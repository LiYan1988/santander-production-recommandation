# %% [markdown]
# ## Feature Engineering and CV based Winners' Solutions
#
# continued from eda_4_28
#
# Trained@2015-06-28, validated@2015-12-28, mlogloss=1.28481
#
# Private score: 0.0302054, public score: 0.0298683
#
# To-do:
# - mean encoding of products grouped by combinations of: canal_entrada, segmento, cod_prov
# - Time since change and lags for a few non-product features:
#     - segmento
#     - ind_actividad_cliente
#     - cod_prov
#     - canal_entrada
#     - indrel_1mes
#     - tiprel_1mes
#
#
# Features:
# - eda_4_28
#     - average of products for each (customer, product) pair
#     - exponent weighted average of products each (customer, product) pair
#     - time since presence of products, distance to the first 1
#     - time to the last positive flank (01)
#     - time to the last negative flank (10)
#     - time to the last 1, to the nearest product purchase
#     - time to the first 1, to the first product purchase
# - before eda_4_25
#     - customer info in the second month
#     - products in the first month
#     - combination of first and second month `ind_actividad_cliente`
#     - combination of first and second month `tiprel_1mes`
#     - combination of first month product by using binary number (`target_combine`)
#     - encoding `target_combine` with
#         - mean number of new products
#         - mean number of customers with new products
#         - mean number of customers with each new products
#     - Count patterns in the last `max_lag` months
#     - Number of month to the last time the customer purchase each product
#         - CV@2015-12-28: mlogloss=1.29349
#         - Private score: 0.0302475, public score: 0.0299266
# - eda_4_25
#     - Use all available history data
#         - E.g., for 2016-05-28 train data, use all previous months, for 2015-02-28, use 1 lag month.
#         - Need to create test set that use the same amount of previous months for each training data set.
#         - This is from [the second winner's solution](https://www.kaggle.com/c/santander-product-recommendation/discussion/26824), his bold part in paragraph 4.
#     - Combine models trained on 2016-05-28 and 2015-06-28:
#         - Private score: 0.0304583, public score: 0.0300839
#         - This is to catch both seasonality and trend, presented in 2015-06-28 and 2016-05-28, respectively.
#         - This idea is mentioned by many winners, like [11-th winner](https://www.kaggle.com/c/santander-product-recommendation/discussion/26823) and [14-th winner](https://www.kaggle.com/c/santander-product-recommendation/discussion/26808)
#
# - eda_4_27
#     - put 2015-06-28 and 2016-05-28 in the same data set, with the same lag=5
#         - Private score:0.0303096, public score: 0.0299867
#         - Different as [11-th winner's discussion](https://www.kaggle.com/c/santander-product-recommendation/discussion/26823)
#             > We tested this by adding 50% of May-16 data to our June model and sure enough, we went from 0.0301 to 0.0303. Then, we built separate models for Jun and May, but the ensemble didn’t work. We weren’t surprised because June data is better for seasonal products, and May data is better for trend products. And vice-versa, June data is bad for trend products and May data is bad for seasonal products. So, they sort of cancelled each other out.
#
#         - But my score is always worse than theirs, maybe this is the reason why we have different observations

# %% [markdown]
# # Draft

# %%
from santander_helper import *

# %%
x_train_june15, y_train_june15 = create_train('2015-06-28', pattern_flag=True)
x_val_june15, y_val_june15 = create_train('2016-05-28', pattern_flag=True)

# %%
def calculate_weight(x_train, y_train):
    '''Calculate weights for xgboost'''
    x_train_ncodpers = pd.concat((x_train.loc[:, 'ncodpers'], y_train), axis=1, ignore_index=True)
    x_train_ncodpers.columns = ['ncodpers', 'n_target']
    x_train_ncodpers = pd.DataFrame(x_train_ncodpers.groupby('ncodpers')['n_target'].count())
    x_train_ncodpers['xgb_weight_1'] = 1.0/x_train_ncodpers['n_target']
    x_train_ncodpers['xgb_weight_2'] = np.exp(1.0/x_train_ncodpers['n_target']-1)
    
    xgb_weight = pd.DataFrame(x_train.loc[:, 'ncodpers'].copy()).join(x_train_ncodpers, on='ncodpers')
    xgb_weight.drop('n_target', axis=1, inplace=True)
    xgb_weight = xgb_weight.iloc[:, 1:].copy()
    
    return xgb_weight

# %%
xgb_weight = calculate_weight(x_train_june15, y_train_june15)

# %%
x_train_june15_ncodpers = pd.concat((x_train_june15.loc[:, 'ncodpers'], y_train_june15), axis=1, ignore_index=True)
x_train_june15_ncodpers.columns = ['ncodpers', 'n_target']
x_train_june15_ncodpers = pd.DataFrame(x_train_june15_ncodpers.groupby('ncodpers')['n_target'].count())
x_train_june15_ncodpers['xgb_weight_1'] = 1.0/x_train_june15_ncodpers['n_target']
x_train_june15_ncodpers['xgb_weight_2'] = np.exp(1.0/x_train_june15_ncodpers['n_target']-1)

xgb_weight = pd.DataFrame(x_train_june15.loc[:, 'ncodpers'].copy()).join(x_train_june15_ncodpers, on='ncodpers')
xgb_weight.drop('n_target', axis=1, inplace=True)
xgb_weight_1 = xgb_weight.iloc[:, 1].values
xgb_weight_2 = xgb_weight.iloc[:, 2].values

# %% [markdown]
# # Test

# %%
from santander_helper import *

# %% [markdown]
# ### 2015-06-28, max_lag=5

# %%
x_train_june15, y_train_june15, weight_train_june15 = create_train('2015-06-28', pattern_flag=True)
x_val_june15, y_val_june15, weight_val_june15 = create_train('2016-05-28', pattern_flag=True)

x_test_june15 = create_test(pattern_flag=True)

param = {'objective': 'multi:softprob', 
         'eta': 0.05, 
         'max_depth': 4, 
         'silent': 1, 
         'num_class': len(target_cols),
         'eval_metric': 'mlogloss',
         'min_child_weight': 1,
         'subsample': 0.7,
         'colsample_bytree': 0.7,
         'seed': 0}
num_rounds = 250
eval_history = {}

# %%
weight_idx = 0
for weight_idx in [0, 1]:
    eval_history[weight_idx] = {}
    dtrain_june15 = xgb.DMatrix(x_train_june15, y_train_june15, weight=weight_train_june15.values[:, weight_idx])
    dval_june15 = xgb.DMatrix(x_val_june15, y_val_june15, weight=weight_val_june15.values[:, weight_idx])
    model_june15 = xgb.train(param, dtrain_june15, num_rounds, 
                             evals=[(dtrain_june15, 'train'), (dval_june15, 'dval')], 
                             verbose_eval=True, evals_result=eval_history[weight_idx])
# Out:
# [0]	train-mlogloss:2.67673	dval-mlogloss:2.69823
# [1]	train-mlogloss:2.49074	dval-mlogloss:2.52495
# [2]	train-mlogloss:2.34356	dval-mlogloss:2.39247
# [3]	train-mlogloss:2.22236	dval-mlogloss:2.28039
# [4]	train-mlogloss:2.11922	dval-mlogloss:2.18952
# [5]	train-mlogloss:2.02934	dval-mlogloss:2.10505
# [6]	train-mlogloss:1.94954	dval-mlogloss:2.03087
# [7]	train-mlogloss:1.87774	dval-mlogloss:1.96457
# [8]	train-mlogloss:1.81368	dval-mlogloss:1.90596
# [9]	train-mlogloss:1.75547	dval-mlogloss:1.85178
# [10]	train-mlogloss:1.70167	dval-mlogloss:1.80365
# [11]	train-mlogloss:1.65222	dval-mlogloss:1.75794
# [12]	train-mlogloss:1.60629	dval-mlogloss:1.71694
# [13]	train-mlogloss:1.56353	dval-mlogloss:1.67702
# [14]	train-mlogloss:1.52385	dval-mlogloss:1.6399
# [15]	train-mlogloss:1.48672	dval-mlogloss:1.60566
# [16]	train-mlogloss:1.45192	dval-mlogloss:1.57349
# [17]	train-mlogloss:1.41942	dval-mlogloss:1.54328
# [18]	train-mlogloss:1.38885	dval-mlogloss:1.51608
# [19]	train-mlogloss:1.36057	dval-mlogloss:1.49131
# [20]	train-mlogloss:1.33374	dval-mlogloss:1.46699
# [21]	train-mlogloss:1.30839	dval-mlogloss:1.44378
# [22]	train-mlogloss:1.28432	dval-mlogloss:1.42132
# [23]	train-mlogloss:1.26142	dval-mlogloss:1.40034
# [24]	train-mlogloss:1.23979	dval-mlogloss:1.38149
# [25]	train-mlogloss:1.21973	dval-mlogloss:1.3629
# [26]	train-mlogloss:1.20055	dval-mlogloss:1.34607
# [27]	train-mlogloss:1.18225	dval-mlogloss:1.32906
# [28]	train-mlogloss:1.16478	dval-mlogloss:1.31405
# [29]	train-mlogloss:1.14812	dval-mlogloss:1.29917
# [30]	train-mlogloss:1.13219	dval-mlogloss:1.2843
# [31]	train-mlogloss:1.11712	dval-mlogloss:1.2701
# [32]	train-mlogloss:1.10256	dval-mlogloss:1.25663
# [33]	train-mlogloss:1.08875	dval-mlogloss:1.24379
# [34]	train-mlogloss:1.07566	dval-mlogloss:1.23161
# [35]	train-mlogloss:1.06303	dval-mlogloss:1.21979
# [36]	train-mlogloss:1.05117	dval-mlogloss:1.20893
# [37]	train-mlogloss:1.03983	dval-mlogloss:1.19875
# [38]	train-mlogloss:1.02886	dval-mlogloss:1.18874
# [39]	train-mlogloss:1.01845	dval-mlogloss:1.17901
# [40]	train-mlogloss:1.00854	dval-mlogloss:1.16986
# [41]	train-mlogloss:0.999056	dval-mlogloss:1.16112
# [42]	train-mlogloss:0.989876	dval-mlogloss:1.15257
# [43]	train-mlogloss:0.980983	dval-mlogloss:1.14448
# [44]	train-mlogloss:0.972489	dval-mlogloss:1.13756
# [45]	train-mlogloss:0.964227	dval-mlogloss:1.13006
# [46]	train-mlogloss:0.956435	dval-mlogloss:1.12274
# [47]	train-mlogloss:0.948899	dval-mlogloss:1.11565
# [48]	train-mlogloss:0.941797	dval-mlogloss:1.10913
# [49]	train-mlogloss:0.934893	dval-mlogloss:1.10248
# [50]	train-mlogloss:0.928338	dval-mlogloss:1.09672
# [51]	train-mlogloss:0.921917	dval-mlogloss:1.09105
# [52]	train-mlogloss:0.915798	dval-mlogloss:1.08564
# [53]	train-mlogloss:0.909829	dval-mlogloss:1.07978
# [54]	train-mlogloss:0.904146	dval-mlogloss:1.07454
# [55]	train-mlogloss:0.898639	dval-mlogloss:1.06961
# [56]	train-mlogloss:0.893374	dval-mlogloss:1.06467
# [57]	train-mlogloss:0.888308	dval-mlogloss:1.05962
# [58]	train-mlogloss:0.883415	dval-mlogloss:1.0551
# [59]	train-mlogloss:0.878567	dval-mlogloss:1.05057
# [60]	train-mlogloss:0.873921	dval-mlogloss:1.04604
# [61]	train-mlogloss:0.86946	dval-mlogloss:1.04202
# [62]	train-mlogloss:0.865231	dval-mlogloss:1.03811
# [63]	train-mlogloss:0.861161	dval-mlogloss:1.03424
# [64]	train-mlogloss:0.857256	dval-mlogloss:1.03102
# [65]	train-mlogloss:0.853385	dval-mlogloss:1.02734
# [66]	train-mlogloss:0.849723	dval-mlogloss:1.02389
# [67]	train-mlogloss:0.846104	dval-mlogloss:1.02053
# [68]	train-mlogloss:0.842631	dval-mlogloss:1.01755
# [69]	train-mlogloss:0.839211	dval-mlogloss:1.01443
# [70]	train-mlogloss:0.835957	dval-mlogloss:1.01147
# [71]	train-mlogloss:0.83272	dval-mlogloss:1.00894
# [72]	train-mlogloss:0.829548	dval-mlogloss:1.00607
# [73]	train-mlogloss:0.826568	dval-mlogloss:1.00361
# [74]	train-mlogloss:0.823696	dval-mlogloss:1.00111
# [75]	train-mlogloss:0.820928	dval-mlogloss:0.999045
# [76]	train-mlogloss:0.818286	dval-mlogloss:0.996711
# [77]	train-mlogloss:0.815683	dval-mlogloss:0.99429
# [78]	train-mlogloss:0.813093	dval-mlogloss:0.991993
# [79]	train-mlogloss:0.810606	dval-mlogloss:0.989735
# [80]	train-mlogloss:0.808167	dval-mlogloss:0.987774
# [81]	train-mlogloss:0.805854	dval-mlogloss:0.985892
# [82]	train-mlogloss:0.803587	dval-mlogloss:0.98392
# [83]	train-mlogloss:0.801326	dval-mlogloss:0.982512
# [84]	train-mlogloss:0.799156	dval-mlogloss:0.980557
# [85]	train-mlogloss:0.79711	dval-mlogloss:0.978448
# [86]	train-mlogloss:0.794953	dval-mlogloss:0.976686
# [87]	train-mlogloss:0.792934	dval-mlogloss:0.974995
# [88]	train-mlogloss:0.791034	dval-mlogloss:0.973204
# [89]	train-mlogloss:0.789126	dval-mlogloss:0.971891
# [90]	train-mlogloss:0.787226	dval-mlogloss:0.97059
# [91]	train-mlogloss:0.785354	dval-mlogloss:0.969351
# [92]	train-mlogloss:0.783641	dval-mlogloss:0.96791
# [93]	train-mlogloss:0.78191	dval-mlogloss:0.966498
# [94]	train-mlogloss:0.780128	dval-mlogloss:0.96512
# [95]	train-mlogloss:0.778574	dval-mlogloss:0.964153
# [96]	train-mlogloss:0.776962	dval-mlogloss:0.962695
# [97]	train-mlogloss:0.775399	dval-mlogloss:0.961222
# [98]	train-mlogloss:0.773871	dval-mlogloss:0.959959
# [99]	train-mlogloss:0.772415	dval-mlogloss:0.95917
# [100]	train-mlogloss:0.770977	dval-mlogloss:0.957982
# [101]	train-mlogloss:0.769617	dval-mlogloss:0.956557
# [102]	train-mlogloss:0.768195	dval-mlogloss:0.955497
# [103]	train-mlogloss:0.766882	dval-mlogloss:0.954452
# [104]	train-mlogloss:0.765546	dval-mlogloss:0.953897
# [105]	train-mlogloss:0.764242	dval-mlogloss:0.952726
# [106]	train-mlogloss:0.762984	dval-mlogloss:0.951704
# [107]	train-mlogloss:0.761773	dval-mlogloss:0.95049
# [108]	train-mlogloss:0.760612	dval-mlogloss:0.94957
# [109]	train-mlogloss:0.759398	dval-mlogloss:0.948535
# [110]	train-mlogloss:0.758294	dval-mlogloss:0.94799
# [111]	train-mlogloss:0.75717	dval-mlogloss:0.947203
# [112]	train-mlogloss:0.756049	dval-mlogloss:0.946455
# [113]	train-mlogloss:0.754927	dval-mlogloss:0.945441
# [114]	train-mlogloss:0.75388	dval-mlogloss:0.944599
# [115]	train-mlogloss:0.752881	dval-mlogloss:0.943988
# [116]	train-mlogloss:0.751864	dval-mlogloss:0.943067
# [117]	train-mlogloss:0.750759	dval-mlogloss:0.942937
# [118]	train-mlogloss:0.749734	dval-mlogloss:0.942145
# [119]	train-mlogloss:0.748786	dval-mlogloss:0.941364
# [120]	train-mlogloss:0.74772	dval-mlogloss:0.940719
# [121]	train-mlogloss:0.746726	dval-mlogloss:0.94012
# [122]	train-mlogloss:0.745831	dval-mlogloss:0.939452
# [123]	train-mlogloss:0.744939	dval-mlogloss:0.938759
# [124]	train-mlogloss:0.744117	dval-mlogloss:0.938201
# [125]	train-mlogloss:0.743189	dval-mlogloss:0.937626
# [126]	train-mlogloss:0.742312	dval-mlogloss:0.936977
# [127]	train-mlogloss:0.741494	dval-mlogloss:0.936754
# [128]	train-mlogloss:0.740642	dval-mlogloss:0.936164
# [129]	train-mlogloss:0.739828	dval-mlogloss:0.935675
# [130]	train-mlogloss:0.738948	dval-mlogloss:0.935223
# [131]	train-mlogloss:0.738141	dval-mlogloss:0.934522
# [132]	train-mlogloss:0.737348	dval-mlogloss:0.934252
# [133]	train-mlogloss:0.736566	dval-mlogloss:0.933809
# [134]	train-mlogloss:0.73577	dval-mlogloss:0.933603
# [135]	train-mlogloss:0.735039	dval-mlogloss:0.932908
# [136]	train-mlogloss:0.734311	dval-mlogloss:0.932658
# [137]	train-mlogloss:0.733585	dval-mlogloss:0.931955
# [138]	train-mlogloss:0.732816	dval-mlogloss:0.931606
# [139]	train-mlogloss:0.73207	dval-mlogloss:0.931197
# [140]	train-mlogloss:0.731397	dval-mlogloss:0.930974
# [141]	train-mlogloss:0.730685	dval-mlogloss:0.930447
# [142]	train-mlogloss:0.730013	dval-mlogloss:0.930033
# [143]	train-mlogloss:0.729362	dval-mlogloss:0.929549
# [144]	train-mlogloss:0.728724	dval-mlogloss:0.928937
# [145]	train-mlogloss:0.728089	dval-mlogloss:0.9287
# [146]	train-mlogloss:0.72743	dval-mlogloss:0.928472
# [147]	train-mlogloss:0.726848	dval-mlogloss:0.928209
# [148]	train-mlogloss:0.726183	dval-mlogloss:0.92769
# [149]	train-mlogloss:0.725637	dval-mlogloss:0.927372
# [150]	train-mlogloss:0.725027	dval-mlogloss:0.927193
# [151]	train-mlogloss:0.724429	dval-mlogloss:0.927018
# [152]	train-mlogloss:0.723799	dval-mlogloss:0.926689
# [153]	train-mlogloss:0.723139	dval-mlogloss:0.926769
# [154]	train-mlogloss:0.722532	dval-mlogloss:0.926403
# [155]	train-mlogloss:0.721909	dval-mlogloss:0.926122
# [156]	train-mlogloss:0.721386	dval-mlogloss:0.925971
# [157]	train-mlogloss:0.720818	dval-mlogloss:0.925725
# [158]	train-mlogloss:0.720252	dval-mlogloss:0.925622
# [159]	train-mlogloss:0.719711	dval-mlogloss:0.92554
# [160]	train-mlogloss:0.719187	dval-mlogloss:0.925367
# [161]	train-mlogloss:0.718665	dval-mlogloss:0.925162
# [162]	train-mlogloss:0.718083	dval-mlogloss:0.924798
# [163]	train-mlogloss:0.717473	dval-mlogloss:0.924462
# [164]	train-mlogloss:0.716901	dval-mlogloss:0.924398
# [165]	train-mlogloss:0.716384	dval-mlogloss:0.924188
# [166]	train-mlogloss:0.715847	dval-mlogloss:0.92389
# [167]	train-mlogloss:0.71534	dval-mlogloss:0.924009
# [168]	train-mlogloss:0.714828	dval-mlogloss:0.924161
# [169]	train-mlogloss:0.714316	dval-mlogloss:0.923908
# [170]	train-mlogloss:0.713778	dval-mlogloss:0.923749
# [171]	train-mlogloss:0.713199	dval-mlogloss:0.923233
# [172]	train-mlogloss:0.712718	dval-mlogloss:0.923015
# [173]	train-mlogloss:0.712263	dval-mlogloss:0.922748
# [174]	train-mlogloss:0.711743	dval-mlogloss:0.92248
# [175]	train-mlogloss:0.71121	dval-mlogloss:0.922251
# [176]	train-mlogloss:0.710711	dval-mlogloss:0.922088
# [177]	train-mlogloss:0.710194	dval-mlogloss:0.921656
# [178]	train-mlogloss:0.70972	dval-mlogloss:0.921897
# [179]	train-mlogloss:0.709252	dval-mlogloss:0.921839
# [180]	train-mlogloss:0.708827	dval-mlogloss:0.921852
# [181]	train-mlogloss:0.708313	dval-mlogloss:0.921785
# [182]	train-mlogloss:0.707862	dval-mlogloss:0.921584
# [183]	train-mlogloss:0.707422	dval-mlogloss:0.921229
# [184]	train-mlogloss:0.706978	dval-mlogloss:0.921073
# [185]	train-mlogloss:0.706554	dval-mlogloss:0.920999
# [186]	train-mlogloss:0.706146	dval-mlogloss:0.921164
# [187]	train-mlogloss:0.705745	dval-mlogloss:0.921153
# [188]	train-mlogloss:0.705303	dval-mlogloss:0.920961
# [189]	train-mlogloss:0.704789	dval-mlogloss:0.9212
# [190]	train-mlogloss:0.704342	dval-mlogloss:0.92118
# [191]	train-mlogloss:0.703934	dval-mlogloss:0.921123
# [192]	train-mlogloss:0.703498	dval-mlogloss:0.921032
# [193]	train-mlogloss:0.703106	dval-mlogloss:0.921217
# [194]	train-mlogloss:0.702695	dval-mlogloss:0.921424
# [195]	train-mlogloss:0.702232	dval-mlogloss:0.92124
# [196]	train-mlogloss:0.701759	dval-mlogloss:0.921216
# [197]	train-mlogloss:0.701286	dval-mlogloss:0.92111
# [198]	train-mlogloss:0.700909	dval-mlogloss:0.920939
# [199]	train-mlogloss:0.700475	dval-mlogloss:0.920743
# [200]	train-mlogloss:0.700035	dval-mlogloss:0.921072
# [201]	train-mlogloss:0.699584	dval-mlogloss:0.921112
# [202]	train-mlogloss:0.699198	dval-mlogloss:0.921077
# [203]	train-mlogloss:0.698798	dval-mlogloss:0.92125
# [204]	train-mlogloss:0.698364	dval-mlogloss:0.921236
# [205]	train-mlogloss:0.697975	dval-mlogloss:0.921365
# [206]	train-mlogloss:0.697499	dval-mlogloss:0.921431
# [207]	train-mlogloss:0.69708	dval-mlogloss:0.921188
# [208]	train-mlogloss:0.696642	dval-mlogloss:0.921368
# [209]	train-mlogloss:0.69617	dval-mlogloss:0.921319
# [210]	train-mlogloss:0.695757	dval-mlogloss:0.921334
# [211]	train-mlogloss:0.695345	dval-mlogloss:0.92159
# [212]	train-mlogloss:0.694946	dval-mlogloss:0.921186
# [213]	train-mlogloss:0.694578	dval-mlogloss:0.9211
# [214]	train-mlogloss:0.694194	dval-mlogloss:0.921054
# [215]	train-mlogloss:0.69377	dval-mlogloss:0.921219
# [216]	train-mlogloss:0.693388	dval-mlogloss:0.921075
# [217]	train-mlogloss:0.693007	dval-mlogloss:0.921085
# [218]	train-mlogloss:0.692638	dval-mlogloss:0.920953
# [219]	train-mlogloss:0.692313	dval-mlogloss:0.920923
# [220]	train-mlogloss:0.691968	dval-mlogloss:0.920882
# [221]	train-mlogloss:0.691606	dval-mlogloss:0.920909
# [222]	train-mlogloss:0.691255	dval-mlogloss:0.921
# [223]	train-mlogloss:0.69083	dval-mlogloss:0.92089
# [224]	train-mlogloss:0.690473	dval-mlogloss:0.921003
# [225]	train-mlogloss:0.690097	dval-mlogloss:0.921007
# [226]	train-mlogloss:0.689704	dval-mlogloss:0.920984
# [227]	train-mlogloss:0.689313	dval-mlogloss:0.920981
# [228]	train-mlogloss:0.688994	dval-mlogloss:0.920896
# [229]	train-mlogloss:0.688664	dval-mlogloss:0.921088
# [230]	train-mlogloss:0.688346	dval-mlogloss:0.921133
# [231]	train-mlogloss:0.687923	dval-mlogloss:0.92122
# [232]	train-mlogloss:0.687567	dval-mlogloss:0.921233
# [233]	train-mlogloss:0.687205	dval-mlogloss:0.921043
# [234]	train-mlogloss:0.686838	dval-mlogloss:0.921158
# [235]	train-mlogloss:0.686534	dval-mlogloss:0.920933
# [236]	train-mlogloss:0.686172	dval-mlogloss:0.920746
# [237]	train-mlogloss:0.685726	dval-mlogloss:0.920674
# [238]	train-mlogloss:0.685382	dval-mlogloss:0.920895
# [239]	train-mlogloss:0.685011	dval-mlogloss:0.920906
# [240]	train-mlogloss:0.684706	dval-mlogloss:0.92086
# [241]	train-mlogloss:0.684365	dval-mlogloss:0.920923
# [242]	train-mlogloss:0.684056	dval-mlogloss:0.920983
# [243]	train-mlogloss:0.683689	dval-mlogloss:0.921142
# [244]	train-mlogloss:0.683291	dval-mlogloss:0.920901
# [245]	train-mlogloss:0.682941	dval-mlogloss:0.921111
# [246]	train-mlogloss:0.682581	dval-mlogloss:0.920975
# [247]	train-mlogloss:0.682221	dval-mlogloss:0.921233
# [248]	train-mlogloss:0.681853	dval-mlogloss:0.921166
# [249]	train-mlogloss:0.681491	dval-mlogloss:0.921252
# [0]	train-mlogloss:2.68853	dval-mlogloss:2.71612
# [1]	train-mlogloss:2.50948	dval-mlogloss:2.55043
# [2]	train-mlogloss:2.36727	dval-mlogloss:2.4193
# [3]	train-mlogloss:2.24981	dval-mlogloss:2.31119
# [4]	train-mlogloss:2.14967	dval-mlogloss:2.22357
# [5]	train-mlogloss:2.06232	dval-mlogloss:2.14174
# [6]	train-mlogloss:1.98454	dval-mlogloss:2.0698
# [7]	train-mlogloss:1.91458	dval-mlogloss:2.00539
# [8]	train-mlogloss:1.85185	dval-mlogloss:1.94818
# [9]	train-mlogloss:1.79484	dval-mlogloss:1.89507
# [10]	train-mlogloss:1.74222	dval-mlogloss:1.84804
# [11]	train-mlogloss:1.69383	dval-mlogloss:1.80353
# [12]	train-mlogloss:1.64888	dval-mlogloss:1.76176
# [13]	train-mlogloss:1.60694	dval-mlogloss:1.72245
# [14]	train-mlogloss:1.56809	dval-mlogloss:1.68616
# [15]	train-mlogloss:1.53165	dval-mlogloss:1.65393
# [16]	train-mlogloss:1.49753	dval-mlogloss:1.6223
# [17]	train-mlogloss:1.46565	dval-mlogloss:1.59275
# [18]	train-mlogloss:1.43567	dval-mlogloss:1.56594
# [19]	train-mlogloss:1.40791	dval-mlogloss:1.54161
# [20]	train-mlogloss:1.38153	dval-mlogloss:1.51767
# [21]	train-mlogloss:1.35658	dval-mlogloss:1.49472
# [22]	train-mlogloss:1.33301	dval-mlogloss:1.47271
# [23]	train-mlogloss:1.31056	dval-mlogloss:1.45259
# [24]	train-mlogloss:1.2893	dval-mlogloss:1.43397
# [25]	train-mlogloss:1.26957	dval-mlogloss:1.41573
# [26]	train-mlogloss:1.25063	dval-mlogloss:1.399
# [27]	train-mlogloss:1.23251	dval-mlogloss:1.3821
# [28]	train-mlogloss:1.2154	dval-mlogloss:1.3662
# [29]	train-mlogloss:1.19903	dval-mlogloss:1.3508
# [30]	train-mlogloss:1.18337	dval-mlogloss:1.33601
# [31]	train-mlogloss:1.16852	dval-mlogloss:1.32194
# [32]	train-mlogloss:1.15416	dval-mlogloss:1.30862
# [33]	train-mlogloss:1.14056	dval-mlogloss:1.29571
# [34]	train-mlogloss:1.1276	dval-mlogloss:1.28353
# [35]	train-mlogloss:1.11515	dval-mlogloss:1.27184
# [36]	train-mlogloss:1.10344	dval-mlogloss:1.26081
# [37]	train-mlogloss:1.09219	dval-mlogloss:1.2505
# [38]	train-mlogloss:1.08136	dval-mlogloss:1.24029
# [39]	train-mlogloss:1.07108	dval-mlogloss:1.23056
# [40]	train-mlogloss:1.06132	dval-mlogloss:1.22182
# [41]	train-mlogloss:1.05187	dval-mlogloss:1.2131
# [42]	train-mlogloss:1.04278	dval-mlogloss:1.20468
# [43]	train-mlogloss:1.03403	dval-mlogloss:1.19675
# [44]	train-mlogloss:1.02559	dval-mlogloss:1.18976
# [45]	train-mlogloss:1.01751	dval-mlogloss:1.18253
# [46]	train-mlogloss:1.00983	dval-mlogloss:1.17541
# [47]	train-mlogloss:1.00245	dval-mlogloss:1.16927
# [48]	train-mlogloss:0.995384	dval-mlogloss:1.16273
# [49]	train-mlogloss:0.988589	dval-mlogloss:1.15628
# [50]	train-mlogloss:0.982105	dval-mlogloss:1.15046
# [51]	train-mlogloss:0.975781	dval-mlogloss:1.14468
# [52]	train-mlogloss:0.96965	dval-mlogloss:1.13908
# [53]	train-mlogloss:0.963665	dval-mlogloss:1.13321
# [54]	train-mlogloss:0.958036	dval-mlogloss:1.128
# [55]	train-mlogloss:0.952561	dval-mlogloss:1.12301
# [56]	train-mlogloss:0.947286	dval-mlogloss:1.1181
# [57]	train-mlogloss:0.942247	dval-mlogloss:1.11318
# [58]	train-mlogloss:0.937363	dval-mlogloss:1.1087
# [59]	train-mlogloss:0.932545	dval-mlogloss:1.10417
# [60]	train-mlogloss:0.92791	dval-mlogloss:1.09957
# [61]	train-mlogloss:0.923457	dval-mlogloss:1.09554
# [62]	train-mlogloss:0.919229	dval-mlogloss:1.09196
# [63]	train-mlogloss:0.915228	dval-mlogloss:1.08819
# [64]	train-mlogloss:0.911301	dval-mlogloss:1.08477
# [65]	train-mlogloss:0.907477	dval-mlogloss:1.08112
# [66]	train-mlogloss:0.90384	dval-mlogloss:1.07778
# [67]	train-mlogloss:0.900186	dval-mlogloss:1.07437
# [68]	train-mlogloss:0.896731	dval-mlogloss:1.07144
# [69]	train-mlogloss:0.893293	dval-mlogloss:1.06819
# [70]	train-mlogloss:0.890025	dval-mlogloss:1.06525
# [71]	train-mlogloss:0.88677	dval-mlogloss:1.06267
# [72]	train-mlogloss:0.883635	dval-mlogloss:1.05981
# [73]	train-mlogloss:0.880652	dval-mlogloss:1.057
# [74]	train-mlogloss:0.877791	dval-mlogloss:1.05441
# [75]	train-mlogloss:0.874995	dval-mlogloss:1.05221
# [76]	train-mlogloss:0.872339	dval-mlogloss:1.04986
# [77]	train-mlogloss:0.869764	dval-mlogloss:1.04756
# [78]	train-mlogloss:0.867119	dval-mlogloss:1.04529
# [79]	train-mlogloss:0.864611	dval-mlogloss:1.04288
# [80]	train-mlogloss:0.862183	dval-mlogloss:1.04095
# [81]	train-mlogloss:0.859881	dval-mlogloss:1.03914
# [82]	train-mlogloss:0.85764	dval-mlogloss:1.03727
# [83]	train-mlogloss:0.855405	dval-mlogloss:1.03571
# [84]	train-mlogloss:0.853225	dval-mlogloss:1.03367
# [85]	train-mlogloss:0.851165	dval-mlogloss:1.03153
# [86]	train-mlogloss:0.849066	dval-mlogloss:1.02972
# [87]	train-mlogloss:0.84703	dval-mlogloss:1.02798
# [88]	train-mlogloss:0.84512	dval-mlogloss:1.02657
# [89]	train-mlogloss:0.843238	dval-mlogloss:1.02517
# [90]	train-mlogloss:0.841315	dval-mlogloss:1.02372
# [91]	train-mlogloss:0.83939	dval-mlogloss:1.02257
# [92]	train-mlogloss:0.837637	dval-mlogloss:1.02125
# [93]	train-mlogloss:0.835907	dval-mlogloss:1.01972
# [94]	train-mlogloss:0.834107	dval-mlogloss:1.01832
# [95]	train-mlogloss:0.832559	dval-mlogloss:1.01716
# [96]	train-mlogloss:0.830948	dval-mlogloss:1.01566
# [97]	train-mlogloss:0.829354	dval-mlogloss:1.01413
# [98]	train-mlogloss:0.82779	dval-mlogloss:1.0129
# [99]	train-mlogloss:0.826336	dval-mlogloss:1.0121
# [100]	train-mlogloss:0.824875	dval-mlogloss:1.01085
# [101]	train-mlogloss:0.823512	dval-mlogloss:1.00952
# [102]	train-mlogloss:0.822121	dval-mlogloss:1.00811
# [103]	train-mlogloss:0.820794	dval-mlogloss:1.00707
# [104]	train-mlogloss:0.819465	dval-mlogloss:1.00643
# [105]	train-mlogloss:0.81817	dval-mlogloss:1.00513
# [106]	train-mlogloss:0.816907	dval-mlogloss:1.00409
# [107]	train-mlogloss:0.815658	dval-mlogloss:1.00285
# [108]	train-mlogloss:0.814457	dval-mlogloss:1.00198
# [109]	train-mlogloss:0.813204	dval-mlogloss:1.0009
# [110]	train-mlogloss:0.812087	dval-mlogloss:0.999935
# [111]	train-mlogloss:0.810963	dval-mlogloss:0.999111
# [112]	train-mlogloss:0.809823	dval-mlogloss:0.99843
# [113]	train-mlogloss:0.808687	dval-mlogloss:0.997499
# [114]	train-mlogloss:0.80762	dval-mlogloss:0.996593
# [115]	train-mlogloss:0.806615	dval-mlogloss:0.996119
# [116]	train-mlogloss:0.80559	dval-mlogloss:0.995595
# [117]	train-mlogloss:0.804506	dval-mlogloss:0.995345
# [118]	train-mlogloss:0.803509	dval-mlogloss:0.994543
# [119]	train-mlogloss:0.802553	dval-mlogloss:0.993776
# [120]	train-mlogloss:0.801461	dval-mlogloss:0.993127
# [121]	train-mlogloss:0.800475	dval-mlogloss:0.992542
# [122]	train-mlogloss:0.799565	dval-mlogloss:0.991625
# [123]	train-mlogloss:0.798678	dval-mlogloss:0.990922
# [124]	train-mlogloss:0.797851	dval-mlogloss:0.990356
# [125]	train-mlogloss:0.796978	dval-mlogloss:0.989868
# [126]	train-mlogloss:0.796077	dval-mlogloss:0.989186
# [127]	train-mlogloss:0.795279	dval-mlogloss:0.989158
# [128]	train-mlogloss:0.794438	dval-mlogloss:0.988571
# [129]	train-mlogloss:0.793613	dval-mlogloss:0.988166
# [130]	train-mlogloss:0.792747	dval-mlogloss:0.987742
# [131]	train-mlogloss:0.791939	dval-mlogloss:0.987072
# [132]	train-mlogloss:0.791145	dval-mlogloss:0.986711
# [133]	train-mlogloss:0.790364	dval-mlogloss:0.986177
# [134]	train-mlogloss:0.789507	dval-mlogloss:0.985899
# [135]	train-mlogloss:0.788788	dval-mlogloss:0.985398
# [136]	train-mlogloss:0.788056	dval-mlogloss:0.984944
# [137]	train-mlogloss:0.787371	dval-mlogloss:0.984226
# [138]	train-mlogloss:0.786604	dval-mlogloss:0.984137
# [139]	train-mlogloss:0.785847	dval-mlogloss:0.983823
# [140]	train-mlogloss:0.785184	dval-mlogloss:0.983638
# [141]	train-mlogloss:0.78448	dval-mlogloss:0.983081
# [142]	train-mlogloss:0.783795	dval-mlogloss:0.982633
# [143]	train-mlogloss:0.783136	dval-mlogloss:0.982105
# [144]	train-mlogloss:0.782506	dval-mlogloss:0.981713
# [145]	train-mlogloss:0.78187	dval-mlogloss:0.981582
# [146]	train-mlogloss:0.781196	dval-mlogloss:0.981058
# [147]	train-mlogloss:0.780595	dval-mlogloss:0.980818
# [148]	train-mlogloss:0.779932	dval-mlogloss:0.980272
# [149]	train-mlogloss:0.779385	dval-mlogloss:0.979931
# [150]	train-mlogloss:0.778805	dval-mlogloss:0.979884
# [151]	train-mlogloss:0.778204	dval-mlogloss:0.979547
# [152]	train-mlogloss:0.777589	dval-mlogloss:0.979165
# [153]	train-mlogloss:0.776988	dval-mlogloss:0.979077
# [154]	train-mlogloss:0.776366	dval-mlogloss:0.97882
# [155]	train-mlogloss:0.77573	dval-mlogloss:0.978485
# [156]	train-mlogloss:0.775205	dval-mlogloss:0.978373
# [157]	train-mlogloss:0.774614	dval-mlogloss:0.977939
# [158]	train-mlogloss:0.774036	dval-mlogloss:0.977772
# [159]	train-mlogloss:0.773505	dval-mlogloss:0.97754
# [160]	train-mlogloss:0.772957	dval-mlogloss:0.977362
# [161]	train-mlogloss:0.772432	dval-mlogloss:0.977147
# [162]	train-mlogloss:0.771836	dval-mlogloss:0.976618
# [163]	train-mlogloss:0.771237	dval-mlogloss:0.976073
# [164]	train-mlogloss:0.7707	dval-mlogloss:0.975992
# [165]	train-mlogloss:0.770207	dval-mlogloss:0.9758
# [166]	train-mlogloss:0.769642	dval-mlogloss:0.975705
# [167]	train-mlogloss:0.769133	dval-mlogloss:0.975474
# [168]	train-mlogloss:0.768611	dval-mlogloss:0.975321
# [169]	train-mlogloss:0.768097	dval-mlogloss:0.975133
# [170]	train-mlogloss:0.76756	dval-mlogloss:0.97491
# [171]	train-mlogloss:0.767015	dval-mlogloss:0.974857
# [172]	train-mlogloss:0.766523	dval-mlogloss:0.974673
# [173]	train-mlogloss:0.76606	dval-mlogloss:0.974429
# [174]	train-mlogloss:0.765527	dval-mlogloss:0.974308
# [175]	train-mlogloss:0.765002	dval-mlogloss:0.974117
# [176]	train-mlogloss:0.764498	dval-mlogloss:0.973942
# [177]	train-mlogloss:0.763976	dval-mlogloss:0.973628
# [178]	train-mlogloss:0.763513	dval-mlogloss:0.973909
# [179]	train-mlogloss:0.763023	dval-mlogloss:0.974082
# [180]	train-mlogloss:0.762558	dval-mlogloss:0.97408
# [181]	train-mlogloss:0.762049	dval-mlogloss:0.973971
# [182]	train-mlogloss:0.761609	dval-mlogloss:0.973766
# [183]	train-mlogloss:0.761158	dval-mlogloss:0.973561
# [184]	train-mlogloss:0.760695	dval-mlogloss:0.973315
# [185]	train-mlogloss:0.76025	dval-mlogloss:0.973243
# [186]	train-mlogloss:0.759846	dval-mlogloss:0.973223
# [187]	train-mlogloss:0.759445	dval-mlogloss:0.973181
# [188]	train-mlogloss:0.758999	dval-mlogloss:0.972935
# [189]	train-mlogloss:0.758488	dval-mlogloss:0.973083
# [190]	train-mlogloss:0.758056	dval-mlogloss:0.973058
# [191]	train-mlogloss:0.757645	dval-mlogloss:0.973027
# [192]	train-mlogloss:0.757224	dval-mlogloss:0.972963
# [193]	train-mlogloss:0.756822	dval-mlogloss:0.973126
# [194]	train-mlogloss:0.756403	dval-mlogloss:0.973383
# [195]	train-mlogloss:0.755978	dval-mlogloss:0.973279
# [196]	train-mlogloss:0.755522	dval-mlogloss:0.973137
# [197]	train-mlogloss:0.755059	dval-mlogloss:0.973382
# [198]	train-mlogloss:0.754687	dval-mlogloss:0.973187
# [199]	train-mlogloss:0.754258	dval-mlogloss:0.973
# [200]	train-mlogloss:0.753825	dval-mlogloss:0.973375
# [201]	train-mlogloss:0.753372	dval-mlogloss:0.973318
# [202]	train-mlogloss:0.752985	dval-mlogloss:0.973243
# [203]	train-mlogloss:0.752579	dval-mlogloss:0.973402
# [204]	train-mlogloss:0.752134	dval-mlogloss:0.973263
# [205]	train-mlogloss:0.751738	dval-mlogloss:0.973474
# [206]	train-mlogloss:0.751263	dval-mlogloss:0.973532
# [207]	train-mlogloss:0.750811	dval-mlogloss:0.973332
# [208]	train-mlogloss:0.750421	dval-mlogloss:0.973488
# [209]	train-mlogloss:0.749959	dval-mlogloss:0.973386
# [210]	train-mlogloss:0.749504	dval-mlogloss:0.973414
# [211]	train-mlogloss:0.749115	dval-mlogloss:0.973315
# [212]	train-mlogloss:0.748725	dval-mlogloss:0.973231
# [213]	train-mlogloss:0.748341	dval-mlogloss:0.97316
# [214]	train-mlogloss:0.747996	dval-mlogloss:0.973055
# [215]	train-mlogloss:0.747613	dval-mlogloss:0.973028
# [216]	train-mlogloss:0.747224	dval-mlogloss:0.972968
# [217]	train-mlogloss:0.746849	dval-mlogloss:0.972936
# [218]	train-mlogloss:0.746477	dval-mlogloss:0.972872
# [219]	train-mlogloss:0.746178	dval-mlogloss:0.972727
# [220]	train-mlogloss:0.745829	dval-mlogloss:0.972707
# [221]	train-mlogloss:0.745446	dval-mlogloss:0.972762
# [222]	train-mlogloss:0.74509	dval-mlogloss:0.97261
# [223]	train-mlogloss:0.744667	dval-mlogloss:0.972503
# [224]	train-mlogloss:0.744316	dval-mlogloss:0.972522
# [225]	train-mlogloss:0.743942	dval-mlogloss:0.972454
# [226]	train-mlogloss:0.743562	dval-mlogloss:0.972431
# [227]	train-mlogloss:0.743153	dval-mlogloss:0.97241
# [228]	train-mlogloss:0.742824	dval-mlogloss:0.972352
# [229]	train-mlogloss:0.74246	dval-mlogloss:0.972674
# [230]	train-mlogloss:0.742158	dval-mlogloss:0.972747
# [231]	train-mlogloss:0.741753	dval-mlogloss:0.972801
# [232]	train-mlogloss:0.741401	dval-mlogloss:0.972805
# [233]	train-mlogloss:0.741047	dval-mlogloss:0.972658
# [234]	train-mlogloss:0.740654	dval-mlogloss:0.97278
# [235]	train-mlogloss:0.740336	dval-mlogloss:0.972577
# [236]	train-mlogloss:0.739974	dval-mlogloss:0.972511
# [237]	train-mlogloss:0.739518	dval-mlogloss:0.972494
# [238]	train-mlogloss:0.739154	dval-mlogloss:0.972698
# [239]	train-mlogloss:0.738764	dval-mlogloss:0.972655
# [240]	train-mlogloss:0.738427	dval-mlogloss:0.972525
# [241]	train-mlogloss:0.738087	dval-mlogloss:0.972512
# [242]	train-mlogloss:0.737774	dval-mlogloss:0.972524
# [243]	train-mlogloss:0.737371	dval-mlogloss:0.972651
# [244]	train-mlogloss:0.73697	dval-mlogloss:0.972443
# [245]	train-mlogloss:0.736606	dval-mlogloss:0.972673
# [246]	train-mlogloss:0.736242	dval-mlogloss:0.97264
# [247]	train-mlogloss:0.735902	dval-mlogloss:0.972892
# [248]	train-mlogloss:0.735556	dval-mlogloss:0.972833
# [249]	train-mlogloss:0.735175	dval-mlogloss:0.972855

# %%
plt.figure(figsize=(16, 9))
plt.rcParams.update({'font.size': 22})
plt.plot(eval_history[0]['train']['mlogloss'], label='train, weight=1/n')
plt.plot(eval_history[0]['dval']['mlogloss'], label='val, weight=1/n')
plt.plot(eval_history[1]['train']['mlogloss'], label='train, weight=exp(1/n-1)')
plt.plot(eval_history[1]['dval']['mlogloss'], label='val, weight=exp(1/n-1)')

# %%
preds_june15 = model_june15.predict(xgb.DMatrix(x_test_june15))

df_preds_june15 = pd.DataFrame(preds_june15, index=x_test_june15.index, columns=target_cols)
# Remove already bought products 
df_preds_june15[x_test_june15[target_cols]==1] = 0 
preds_june15 = df_preds_june15.values
preds_june15 = np.argsort(preds_june15, axis=1)
preds_june15 = np.fliplr(preds_june15)[:, :7]

test_id = x_test_june15.loc[:, 'ncodpers'].values
final_preds_june15 = [' '.join([target_cols[k] for k in pred]) for pred in preds_june15]

out_df_june15 = pd.DataFrame({'ncodpers': test_id, 'added_products': final_preds_june15})
out_df_june15.to_csv('eda_4_28_june15_it100.csv.gz', compression='gzip', index=False)

# %% [markdown]
# ### 2016-05-28, max_lag=16

# %%
x_train_may16, y_train_may16 = create_train('2015-05-28', pattern_flag=True, max_lag=16)

x_test_may16 = create_test(pattern_flag=True)

param = {'objective': 'multi:softprob', 
         'eta': 0.05, 
         'max_depth': 8, 
         'silent': 1, 
         'num_class': len(target_cols),
         'eval_metric': 'mlogloss',
         'min_child_weight': 1,
         'subsample': 0.7,
         'colsample_bytree': 0.7,
         'seed': 0}
num_rounds = 60

dtrain_may16 = xgb.DMatrix(x_train_may16.values, y_train_may16.values)
model_may16 = xgb.train(param, dtrain_may16, num_rounds, evals=[(dtrain_may16, 'train')], verbose_eval=True)

preds_may16 = model_may16.predict(xgb.DMatrix(x_test_may16.values))

df_preds_may16 = pd.DataFrame(preds_may16, index=x_test_may16.index, columns=target_cols)
# Remove already bought products 
df_preds_may16[x_test_may16[target_cols]==1] = 0 
preds_may16 = df_preds_may16.values
preds_may16 = np.argsort(preds_may16, axis=1)
preds_may16 = np.fliplr(preds_may16)[:, :7]

test_id = x_test_may16.loc[:, 'ncodpers'].values
final_preds_may16 = [' '.join([target_cols[k] for k in pred]) for pred in preds_may16]

out_df_may16 = pd.DataFrame({'ncodpers': test_id, 'added_products': final_preds_may16})
out_df_may16.to_csv('eda_4_28_may16.csv.gz', compression='gzip', index=False)
# Out:
# [0]	train-mlogloss:2.64321
# [1]	train-mlogloss:2.42916
# [2]	train-mlogloss:2.26143
# [3]	train-mlogloss:2.12057
# [4]	train-mlogloss:2.00099
# [5]	train-mlogloss:1.89603
# [6]	train-mlogloss:1.80356
# [7]	train-mlogloss:1.72067
# [8]	train-mlogloss:1.64465
# [9]	train-mlogloss:1.57663
# [10]	train-mlogloss:1.51355
# [11]	train-mlogloss:1.45557
# [12]	train-mlogloss:1.40214
# [13]	train-mlogloss:1.35231
# [14]	train-mlogloss:1.30587
# [15]	train-mlogloss:1.26249
# [16]	train-mlogloss:1.222
# [17]	train-mlogloss:1.18383
# [18]	train-mlogloss:1.14811
# [19]	train-mlogloss:1.11448
# [20]	train-mlogloss:1.08268
# [21]	train-mlogloss:1.0525
# [22]	train-mlogloss:1.02404
# [23]	train-mlogloss:0.997108
# [24]	train-mlogloss:0.971606
# [25]	train-mlogloss:0.947348
# [26]	train-mlogloss:0.924398
# [27]	train-mlogloss:0.902768
# [28]	train-mlogloss:0.881792
# [29]	train-mlogloss:0.861978
# [30]	train-mlogloss:0.842969
# [31]	train-mlogloss:0.824979
# [32]	train-mlogloss:0.80799
# [33]	train-mlogloss:0.791558
# [34]	train-mlogloss:0.776193
# [35]	train-mlogloss:0.761276
# [36]	train-mlogloss:0.746991
# [37]	train-mlogloss:0.733397
# [38]	train-mlogloss:0.720404
# [39]	train-mlogloss:0.707905
# [40]	train-mlogloss:0.696077
# [41]	train-mlogloss:0.684611
# [42]	train-mlogloss:0.673712
# [43]	train-mlogloss:0.66345
# [44]	train-mlogloss:0.653513
# [45]	train-mlogloss:0.643782
# [46]	train-mlogloss:0.634649
# [47]	train-mlogloss:0.625692
# [48]	train-mlogloss:0.617063
# [49]	train-mlogloss:0.608998
# [50]	train-mlogloss:0.60114
# [51]	train-mlogloss:0.593598
# [52]	train-mlogloss:0.586282
# [53]	train-mlogloss:0.57932
# [54]	train-mlogloss:0.57262
# [55]	train-mlogloss:0.566129
# [56]	train-mlogloss:0.560005
# [57]	train-mlogloss:0.554003
# [58]	train-mlogloss:0.548272
# [59]	train-mlogloss:0.542817

# %% [markdown]
# ### Combine two models

# %%
preds_june15 = model_june15.predict(xgb.DMatrix(x_test_june15.values))
preds_may16 = model_may16.predict(xgb.DMatrix(x_test_may16.values))

preds1 = np.sqrt(preds_june15*preds_may16)
preds2 = 0.5*preds_june15 + 0.5*preds_may16

# Geometry mean
df_preds1 = pd.DataFrame(preds1, index=x_test_may16.index, columns=target_cols)
# Remove already bought products 
df_preds1[x_test_may16[target_cols]==1] = 0 
preds1 = df_preds1.values
preds1 = np.argsort(preds1, axis=1)
preds1 = np.fliplr(preds1)[:, :7]

test_id = x_test_may16.loc[:, 'ncodpers'].values
final_preds1 = [' '.join([target_cols[k] for k in pred]) for pred in preds1]

out_df1 = pd.DataFrame({'ncodpers': test_id, 'added_products': final_preds1})
out_df1.to_csv('eda_4_28_gm.csv.gz', compression='gzip', index=False)

# Algorithmic mean
df_preds2 = pd.DataFrame(preds2, index=x_test_may16.index, columns=target_cols)
# Remove already bought products 
df_preds2[x_test_may16[target_cols]==1] = 0 
preds2 = df_preds2.values
preds2 = np.argsort(preds2, axis=1)
preds2 = np.fliplr(preds2)[:, :7]

test_id = x_test_may16.loc[:, 'ncodpers'].values
final_preds2 = [' '.join([target_cols[k] for k in pred]) for pred in preds2]

out_df2 = pd.DataFrame({'ncodpers': test_id, 'added_products': final_preds2})
out_df2.to_csv('eda_4_28_am.csv.gz', compression='gzip', index=False)
