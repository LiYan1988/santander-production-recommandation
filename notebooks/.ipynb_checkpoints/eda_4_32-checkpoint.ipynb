# %% [markdown]
# ## Feature Engineering and CV based Winners' Solutions
#
# continued from eda_4_26
#
# New in this notebook:
# - Trained@2015-06-28, validated@2015-12-28, MAP@7=0.858, private LB=0.0302798, public LB=0.0298547

# %%
from santander_helper import *

# %%
param = {'objective': 'multi:softprob', 
         'eta': 0.05, 
         'max_depth': 9, 
         'silent': 1, 
         'num_class': len(target_cols),
         'eval_metric': 'mlogloss',
         'min_child_weight': 1,
         'subsample': 0.7,
         'colsample_bytree': 0.7,
         'seed': 0}
num_rounds = 20

history, model_dict, y_pred, y_sub = \
    train_test_month(param, num_rounds, '2015-06-28', '2016-05-28', 
    'eda_4_32.csv.gz', n_repeat=10, random_seed=54, n_features=None)
# Out:
# Train, validate, and predict, repetition 0 of 3
# [0]	train-mlogloss:2.67452	val-mlogloss:2.70254	train-MAP@7:0.887959	val-MAP@7:0.828629
# [1]	train-mlogloss:2.48487	val-mlogloss:2.532	train-MAP@7:0.892384	val-MAP@7:0.836623
# [2]	train-mlogloss:2.33461	val-mlogloss:2.39766	train-MAP@7:0.895233	val-MAP@7:0.843312
# [3]	train-mlogloss:2.21104	val-mlogloss:2.28978	train-MAP@7:0.896585	val-MAP@7:0.841969
# [4]	train-mlogloss:2.10473	val-mlogloss:2.19421	train-MAP@7:0.897956	val-MAP@7:0.845021
# [5]	train-mlogloss:2.01194	val-mlogloss:2.11498	train-MAP@7:0.898751	val-MAP@7:0.846274
# [6]	train-mlogloss:1.92949	val-mlogloss:2.04881	train-MAP@7:0.899308	val-MAP@7:0.847755
# [7]	train-mlogloss:1.85608	val-mlogloss:1.99006	train-MAP@7:0.899953	val-MAP@7:0.84947
# [8]	train-mlogloss:1.78903	val-mlogloss:1.93101	train-MAP@7:0.900402	val-MAP@7:0.849752
# [9]	train-mlogloss:1.72784	val-mlogloss:1.87626	train-MAP@7:0.901675	val-MAP@7:0.850532
# [10]	train-mlogloss:1.67174	val-mlogloss:1.82908	train-MAP@7:0.902023	val-MAP@7:0.850824
# [11]	train-mlogloss:1.62017	val-mlogloss:1.7865	train-MAP@7:0.902844	val-MAP@7:0.851204
# [12]	train-mlogloss:1.57212	val-mlogloss:1.74694	train-MAP@7:0.90343	val-MAP@7:0.850725
# [13]	train-mlogloss:1.52761	val-mlogloss:1.70894	train-MAP@7:0.904109	val-MAP@7:0.850696
# [14]	train-mlogloss:1.48647	val-mlogloss:1.67513	train-MAP@7:0.904714	val-MAP@7:0.850854
# [15]	train-mlogloss:1.44796	val-mlogloss:1.64211	train-MAP@7:0.905083	val-MAP@7:0.851726
# [16]	train-mlogloss:1.41155	val-mlogloss:1.61561	train-MAP@7:0.9057	val-MAP@7:0.851972
# [17]	train-mlogloss:1.37729	val-mlogloss:1.58884	train-MAP@7:0.906122	val-MAP@7:0.85222
# [18]	train-mlogloss:1.34492	val-mlogloss:1.56119	train-MAP@7:0.906553	val-MAP@7:0.852383
# [19]	train-mlogloss:1.31483	val-mlogloss:1.53552	train-MAP@7:0.906827	val-MAP@7:0.852553
# [20]	train-mlogloss:1.28609	val-mlogloss:1.5137	train-MAP@7:0.907209	val-MAP@7:0.852336
# [21]	train-mlogloss:1.25904	val-mlogloss:1.49001	train-MAP@7:0.907671	val-MAP@7:0.852719
# [22]	train-mlogloss:1.2337	val-mlogloss:1.46907	train-MAP@7:0.908127	val-MAP@7:0.852765
# [23]	train-mlogloss:1.20962	val-mlogloss:1.44981	train-MAP@7:0.908527	val-MAP@7:0.852777
# [24]	train-mlogloss:1.18641	val-mlogloss:1.43042	train-MAP@7:0.908998	val-MAP@7:0.85295
# [25]	train-mlogloss:1.16466	val-mlogloss:1.4143	train-MAP@7:0.909177	val-MAP@7:0.852862
# [26]	train-mlogloss:1.14377	val-mlogloss:1.39712	train-MAP@7:0.909546	val-MAP@7:0.852898
# [27]	train-mlogloss:1.1243	val-mlogloss:1.38057	train-MAP@7:0.909801	val-MAP@7:0.85302
# [28]	train-mlogloss:1.10559	val-mlogloss:1.36539	train-MAP@7:0.910211	val-MAP@7:0.853245
# [29]	train-mlogloss:1.08752	val-mlogloss:1.35075	train-MAP@7:0.910473	val-MAP@7:0.853178
# [30]	train-mlogloss:1.07027	val-mlogloss:1.33517	train-MAP@7:0.910784	val-MAP@7:0.853647
# [31]	train-mlogloss:1.05384	val-mlogloss:1.32123	train-MAP@7:0.911071	val-MAP@7:0.853959
# [32]	train-mlogloss:1.03832	val-mlogloss:1.30946	train-MAP@7:0.911556	val-MAP@7:0.85385
# [33]	train-mlogloss:1.02355	val-mlogloss:1.29679	train-MAP@7:0.91173	val-MAP@7:0.854144
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-5db6bbb7bbd6> in <module>
#      13 history, model_dict, y_pred, y_sub = \
#      14     train_test_month(param, num_rounds, '2015-06-28', '2016-05-28',
# ---> 15     'eda_4_32.csv.gz', n_repeat=3, random_seed=54, n_features=None)
#
# ~\Desktop\santander-production-recommandation\notebooks\santander_helper.py in train_test_month(param, num_rounds, month_train, month_val, sub_name, month_test, n_repeat, random_seed, max_lag, fixed_lag, verbose_eval, n_features)
#    1263         model = xgb.train(param, dtrain, num_rounds, evals=[(dtrain, 'train'), (dval, 'val')],
#    1264             verbose_eval=verbose_eval, feval=eval_map, evals_result=history[n],
# -> 1265             gt=ground_truth, ts=data_len)
#    1266         model_dict[n] = model
#    1267         y_tmp = model.predict(dtest)
#
# ~\AppData\Local\Continuum\miniconda3\envs\kaggle\lib\site-packages\xgboost\training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates, **kwargs_eval)
#     202                            evals=evals,
#     203                            obj=obj, feval=feval,
# --> 204                            xgb_model=xgb_model, callbacks=callbacks, **kwargs_eval)
#     205
#     206
#
# ~\AppData\Local\Continuum\miniconda3\envs\kaggle\lib\site-packages\xgboost\training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks, **kwargs_eval)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# ~\AppData\Local\Continuum\miniconda3\envs\kaggle\lib\site-packages\xgboost\core.py in update(self, dtrain, iteration, fobj)
#     892         if fobj is None:
#     893             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, ctypes.c_int(iteration),
# --> 894                                                     dtrain.handle))
#     895         else:
#     896             pred = self.predict(dtrain)
#
# KeyboardInterrupt:

# %%
history_train = history.xs(axis=1, level=[1, 2], key=['train', 'MAP@7']).copy()
history_train['mean'] = history_train.iloc[:, :3].mean(axis=1)
history_train['std'] = history_train.iloc[:, :3].std(axis=1)

history_val = history.xs(axis=1, level=[1, 2], key=['val', 'MAP@7']).copy()
history_val['mean'] = history_val.iloc[:, :3].mean(axis=1)
history_val['std'] = history_val.iloc[:, :3].std(axis=1)

# %%
plt.figure(figsize=(16, 9))
# plt.plot(history_train['mean'])
# plt.fill_between(history_train.index, history_train['mean']+history_train['std'], history_train['mean']-history_train['std'], alpha=0.3)

plt.plot(history_val['mean'])
plt.fill_between(history_val.index, history_val['mean']+history_val['std'], history_val['mean']-history_val['std'], alpha=0.3)

plt.grid()

# %%
fi = pd.DataFrame({i: model_dict[i].get_score(importance_type='gain') for i in range(3)})
fi['mean'] = fi.iloc[:, :3].mean(axis=1)
fi['std'] = fi.iloc[:, :3].std(axis=1)
fi.sort_values(by=['mean'], inplace=True, ascending=False)
# fi.reset_index(inplace=True)
# fi.to_csv('feature_importance.csv')

# %%
plt.rcParams.update({'figure.figsize': '16, 240'})
plt.rcParams.update({'font.size': '22'})
fig, ax = plt.subplots()
ax.barh(fi.index, fi['mean'].values, log=True, xerr=fi['std'].values)
ax.grid()
ax.tick_params(labelbottom=True,labeltop=True)
ax.set_ylim(fi.shape[0], -0.5)
# Out:
# (386, -0.5)

# %%
plt.figure(figsize=(16, 9))
plt.plot(fi.values[:, 3])
plt.grid()
plt.yscale('log')
