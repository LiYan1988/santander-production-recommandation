# %% [markdown]
# # Combine the two kernels

# %% [markdown]
# ## Clean Data

# %%
import os
if os.name=='nt':
    try:
        mingw_path = 'C:\\Program Files\\mingw-w64\\x86_64-8.1.0-posix-seh-rt_v6-rev0\\mingw64\\bin'
        os.environ['PATH'] = mingw_path + ';' + os.environ['PATH']
    except:
        pass
    
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('../input/train_ver2.csv')
df2 = df.copy()
# Out:
# C:\Users\lyaa\AppData\Local\Continuum\miniconda3\envs\kaggle\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (5,8,11,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.to_hdf('../input/data.hdf', 'train_ver2', complib='blosc:lz4', complevel=9, format='t')

# %%
df.memory_usage(deep=True).sum()/2**30
# Out:
# 15.328144772909582

# %% [markdown]
# Some columns have the same number of nulls, these are the same samples. Nulls are filled with 'unknown'

# %%
dfnull = df.isnull().sum()
dfnull
# Out:
# fecha_dato                      0
# ncodpers                        0
# ind_empleado                27734
# pais_residencia             27734
# sexo                        27804
# age                             0
# fecha_alta                  27734
# ind_nuevo                   27734
# antiguedad                      0
# indrel                      27734
# ult_fec_cli_1t           13622516
# indrel_1mes                149781
# tiprel_1mes                149781
# indresi                     27734
# indext                      27734
# conyuemp                 13645501
# canal_entrada              186126
# indfall                     27734
# tipodom                     27735
# cod_prov                    93591
# nomprov                     93591
# ind_actividad_cliente       27734
# renta                     2794375
# segmento                   189368
# ind_ahor_fin_ult1               0
# ind_aval_fin_ult1               0
# ind_cco_fin_ult1                0
# ind_cder_fin_ult1               0
# ind_cno_fin_ult1                0
# ind_ctju_fin_ult1               0
# ind_ctma_fin_ult1               0
# ind_ctop_fin_ult1               0
# ind_ctpp_fin_ult1               0
# ind_deco_fin_ult1               0
# ind_deme_fin_ult1               0
# ind_dela_fin_ult1               0
# ind_ecue_fin_ult1               0
# ind_fond_fin_ult1               0
# ind_hip_fin_ult1                0
# ind_plan_fin_ult1               0
# ind_pres_fin_ult1               0
# ind_reca_fin_ult1               0
# ind_tjcr_fin_ult1               0
# ind_valo_fin_ult1               0
# ind_viv_fin_ult1                0
# ind_nomina_ult1             16063
# ind_nom_pens_ult1           16063
# ind_recibo_ult1                 0
# dtype: int64

# %%
column_fillna_with_unkonwn = [c for c in dfnull.index if dfnull[c]==27734] # columns that NA is filled by 'unknown'
column_fillna_with_unkonwn
# Out:
# ['ind_empleado',
#  'pais_residencia',
#  'fecha_alta',
#  'ind_nuevo',
#  'indrel',
#  'indresi',
#  'indext',
#  'indfall',
#  'ind_actividad_cliente']

# %%
column_fillna_with_unkonwn.remove('fecha_alta')

# %%
column_fillna_with_unkonwn
# Out:
# ['ind_empleado',
#  'pais_residencia',
#  'ind_nuevo',
#  'indrel',
#  'indresi',
#  'indext',
#  'indfall',
#  'ind_actividad_cliente']

# %%
for c in column_fillna_with_unkonwn:
    df.loc[df[c].isnull(), c] = 'unknown'
    print(df[c].value_counts(dropna=False))
    print(df[c].isnull().sum())
    print()
# Out:
# N          13610977
# unknown       27734
# B              3566
# F              2523
# A              2492
# S                17
# Name: ind_empleado, dtype: int64
# 0
#
# ES         13553710
# unknown       27734
# FR             5161
# AR             4835
# DE             4625
# GB             4605
# US             3651
# CO             3526
# IT             2947
# RO             2931
# MX             2573
# BR             2351
# VE             2331
# EC             2169
# CH             1995
# BE             1526
# BO             1514
# PY             1430
# PT             1419
# CL              989
# PE              900
# RU              769
# CU              758
# NL              757
# SE              603
# PL              599
# CN              563
# UY              510
# UA              493
# BG              476
#              ...
# CG               34
# VN               34
# ET               34
# TW               34
# OM               22
# IS               17
# GH               17
# ML               17
# AL               17
# CD               17
# CF               17
# GM               17
# KH               17
# TG               17
# MM               17
# GE               17
# LV               17
# KZ               17
# LB               17
# LY               17
# BZ               17
# SL               17
# GI               17
# KW               17
# TN               17
# ZW               11
# DJ               11
# JM               11
# BM                6
# MT                2
# Name: pais_residencia, Length: 119, dtype: int64
# 0
#
# 0.0        12808368
# 1.0          811207
# unknown       27734
# Name: ind_nuevo, dtype: int64
# 0
#
# 1.0        13594782
# unknown       27734
# 99.0          24793
# Name: indrel, dtype: int64
# 0
#
# S          13553711
# N             65864
# unknown       27734
# Name: indresi, dtype: int64
# 0
#
# N          12974839
# S            644736
# unknown       27734
# Name: indext, dtype: int64
# 0
#
# N          13584813
# S             34762
# unknown       27734
# Name: indfall, dtype: int64
# 0
#
# 0.0        7384390
# 1.0        6235185
# unknown      27734
# Name: ind_actividad_cliente, dtype: int64
# 0

# %%
dfnull = df.isnull().sum()

# %%
dfnull
# Out:
# fecha_dato                      0
# ncodpers                        0
# ind_empleado                    0
# pais_residencia                 0
# sexo                        27804
# age                             0
# fecha_alta                  27734
# ind_nuevo                       0
# antiguedad                      0
# indrel                          0
# ult_fec_cli_1t           13622516
# indrel_1mes                149781
# tiprel_1mes                149781
# indresi                         0
# indext                          0
# conyuemp                 13645501
# canal_entrada              186126
# indfall                         0
# tipodom                     27735
# cod_prov                    93591
# nomprov                     93591
# ind_actividad_cliente           0
# renta                     2794375
# segmento                   189368
# ind_ahor_fin_ult1               0
# ind_aval_fin_ult1               0
# ind_cco_fin_ult1                0
# ind_cder_fin_ult1               0
# ind_cno_fin_ult1                0
# ind_ctju_fin_ult1               0
# ind_ctma_fin_ult1               0
# ind_ctop_fin_ult1               0
# ind_ctpp_fin_ult1               0
# ind_deco_fin_ult1               0
# ind_deme_fin_ult1               0
# ind_dela_fin_ult1               0
# ind_ecue_fin_ult1               0
# ind_fond_fin_ult1               0
# ind_hip_fin_ult1                0
# ind_plan_fin_ult1               0
# ind_pres_fin_ult1               0
# ind_reca_fin_ult1               0
# ind_tjcr_fin_ult1               0
# ind_valo_fin_ult1               0
# ind_viv_fin_ult1                0
# ind_nomina_ult1             16063
# ind_nom_pens_ult1           16063
# ind_recibo_ult1                 0
# dtype: int64

# %% [markdown]
# `sexo`: nulls are filled with 'unknown'

# %%
df.loc[df.sexo.isnull(), 'sexo'] = 'unknown'

# %% [markdown]
# ### `ult_fec_cli_1t`
#
# Last date as primary customer (if he isn't at the end of the month)
#
# Only very few samples in `ult_fec_cli_1t` is not NA, 24793 out of 13,647,309 samples have `ult_fec_cli_1t` not NA.
#
# 1. If the sample is not NA
#     - `indrel_1mes==1`: the customer was primary at the beginning of the month, but left
#     - But `indrel_1mes` can be values other than 1, following possibilities
#         - The customer became primary at some time of the month and then left immediately in the same month
#         - OR, `ult_fec_cli_1t` also records other changes of customer types
#         - OR, the data is not consistent for a few samples
# 2. A customer can become and leave primary multiple times, `ult_fec_cli_1t` only records the change of the current primary membership
#     - `df.ult_fec_cli_1t-df.fecha_dato<=-30 days`
#     - `df.ult_fec_cli_1t-df.fecha_dato` can be positive, meaning the current membership changes in a future date
# 3. If the sample is NA
#     - The customer is not primary up to the end of the month
#     - The customer is still primary at the end of the month
#
# #### Findings in data analysis
# 1. `ult_fec_cli_1t` is defined a posteriori, it defines the termination of primary of each primary period
# 2. The definition of `indrel` does not match with data. It simply indicates if `ult_fec_cli_1t` is NA or not.
#     - `ult_fec_cli_1t` is NA, `indrel==1`
#     - `ult_fec_cli_1t` is not NA, `indrel==99`
# 3.

# %%
df.shape
# Out:
# (13647309, 48)

# %%
df.ult_fec_cli_1t.value_counts(dropna=False).head()
# Out:
# NaN           13622516
# 2015-12-24         763
# 2015-12-28         521
# 2015-07-09         443
# 2015-07-06         405
# Name: ult_fec_cli_1t, dtype: int64

# %%
a = df.loc[df.ult_fec_cli_1t.notnull(), ['ncodpers', 'fecha_dato', 'fecha_alta', 'ult_fec_cli_1t', 'indrel', 'indrel_1mes']]
a.fecha_dato = pd.to_datetime(a.fecha_dato)
a.fecha_alta = pd.to_datetime(a.fecha_alta)
a.ult_fec_cli_1t = pd.to_datetime(a.ult_fec_cli_1t)

# %% [markdown]
# #### `ult_fec_cli_1t` and `fecha_dato`
#
# - `ult_fec_cli_1t-fecha_dato>=-27 days`
# - `ult_fec_cli_1t-fecha_dato<=183 days`
#
# `ult_fec_cli_1t` is always in the current or a future month. So it tells when this current primary membership is terminated **a posteriori**.

# %%
b = (a.ult_fec_cli_1t - a.fecha_dato).value_counts().sort_index()
c = b.copy()
c.index = c.index.astype('timedelta64[M]')
c = c.groupby(by=c.index).sum()

# %%
b.head()
# Out:
# -27 days    769
# -26 days    725
# -25 days    571
# -24 days    686
# -23 days    644
# dtype: int64

# %%
b.tail()
# Out:
# 177 days    37
# 180 days    24
# 181 days    37
# 182 days    26
# 183 days    25
# dtype: int64

# %%
c
# Out:
# -1    18236
#  0     2557
#  1      747
#  2      829
#  3      774
#  4      887
#  5      738
#  6       25
# dtype: int64

# %% [markdown]
# Conversely, if `ult_fec_cli_1t` is NA, change from primary to non-primary should never happen. If we compare `indrel_1mes` of this month with that of the next month for the same customer, it should never change from 1 to not 1.

# %% [markdown]
# So there are three types of customers
# 1. `ult_fec_cli_1t` is always NA
#     - Customer type should always be primary or not primary, never change between primary and not primary
#     - 925932 customers
#     - Among these customers, 921072 have an unchanged `indrel_1mes`
#         - Among these customers, most of them have `indrel_1mes==1`
#     - Only 4860 customers have two `indrel_1mes`
#         - How about the other customers whose `indrel_1mes!=1`? Their `indrel_1mes` should change from other types to 1 and **do not change back**
#             - **exceptions, `ult_fec_cli_1t` missing, but should have a number**
#                 - 23 customers whose `indrel_1mes` changes from 1 to 3 then to 1 again
#                 - 4 customers whose `indrel_1mes` changes from 1 to 3, 3 all occur at 2016-05, the last month
#                 - 1 customer's `indrel_1mes` changes from 3 to 1 to 3 to 1, `ncodpers==693087`
#             - **others, become primary and stay**
#                 - 2741 customers' `indrel_1mes` changes from 3 to 1
#                 - 1120 customers `indrel_1mes` changes from 2 to 1
#                 - 730 customers `indrel_1mes` changes from 'P' to 1
#                 - 241 customers `indrel_1mes` changes from 4 to 1
# 2. `ult_fec_cli_1t` is always not NA
#     - 3481 customers, all the them have been primary once and then changed types
#     - 13 customers have two types of `indrel_1mes`, which change between 1 and other types (usually 3 indicating former primary or P, potential customer)
#     - 3468 customers have only one  type of `indrel_1mes`, but they may have multiple samples. This indicates
#         - either the data is wrong
#         - or, they change to primary and then change back within the same month, so `indrel_1mes` do not change in the next month.
#         - For those customers fullfill the following condition, are they deliberate?
#             - with multiple samples
#             - `indrel_1mes` are the same
#             - `ult_fec_cli_1t` are different
#     - we can count the unique values of `ult_fec_cli_1i` to determine how many times
# 3. `ult_fec_cli_1t` changes between NA and not NA
#     - 12546 customers

# %%
4860-23-4-1-2741-1120-730-241
# Out:
# 0

# %%
d = df.loc[:, ['ncodpers', 'indrel_1mes', 'fecha_dato', 'ult_fec_cli_1t']]
d.fecha_dato = pd.to_datetime(d.fecha_dato)
d.ult_fec_cli_1t = pd.to_datetime(d.ult_fec_cli_1t)
d.sort_values(by=['ncodpers', 'fecha_dato'], ascending=[True, True], inplace=True)
d = d.loc[d.indrel_1mes.notnull(), :] # drop samples without indrel_1mes
d.indrel_1mes.unique()
indrel_map = {1.0: 1, '1': 1, '2': 2, 2.0: 2, '1.0': 1, '2.0': 2, 4.0: 4, '3.0': 3, 3.0: 3, '4.0': 4, 'P': 'P', '3': 3,
       '4': 4}
d.loc[:, 'indrel_1mes'] = d.indrel_1mes.map(indrel_map)

# %%
def count_null(x):
    return x.isnull().sum()

def count_all(x):
    return len(x)

e = d.groupby(['ncodpers'])['ult_fec_cli_1t'].agg([count_null, count_all])
e['diff'] = e.count_all-e.count_null
e.sort_values(by=['diff', 'count_all'], axis=0, ascending=[True, False], inplace=True)

# %% [markdown]
# Number of customers whose `ult_fec_cli_1t` is always NA is 925932

# %%
e.loc[(e['diff']==0) & (e['count_null']>0)].shape
# Out:
# (925932, 3)

# %% [markdown]
# Number of customers whose `ult_fec_cli_1t` is always not NA is 3481

# %%
e.count_null.value_counts().sort_index().iloc[0]
# Out:
# 3481

# %% [markdown]
# Number of customers whose `ult_fec_cli_1t` changes between NA and not NA

# %%
e.loc[(e['diff']>0) & (e.count_null>0)].shape
# Out:
# (12546, 3)

# %% [markdown]
# All the cases are searched

# %%
12546+3481+925932-e.shape[0]
# Out:
# 0

# %% [markdown]
# ##### Customers whose `ult_fec_cli_1t` is always NA
#
# How their `indrel_1mes` change through different months?

# %%
e1 = e.loc[(e['diff']==0) & (e['count_null']>0)].index.tolist() # list of costumer id with ult_fec_cli_1t always NA

# %%
d.columns
# Out:
# Index(['ncodpers', 'indrel_1mes', 'fecha_dato', 'ult_fec_cli_1t'], dtype='object')

# %%
d1 = d.loc[d.ncodpers.isin(e1), ['ncodpers', 'indrel_1mes', 'fecha_dato']]
d1.sort_values(['ncodpers', 'fecha_dato'], inplace=True)

# %%
d1.head(1)
# Out:
#         ncodpers indrel_1mes fecha_dato
# 416965     15889           1 2015-01-28

# %%
d1_group = d1.groupby('ncodpers')
a = d1_group.get_group(15889)

# %%
def count_types(x):
    return len(x.value_counts().index.tolist())

def condense_types(x):
    return x.value_counts().index.tolist()

# %%
d1_count_types = d1_group['indrel_1mes'].apply(count_types)

# %%
d1_count_types.value_counts()
# Out:
# 1    921072
# 2      4860
# Name: indrel_1mes, dtype: int64

# %%
4860+921072-925932
# Out:
# 0

# %% [markdown]
# Most of the customers whose `ult_fec_cli_1t` is always NA and `indrel_1mes` unchanged have `indrel_1mes==1`

# %%
d.loc[d.ncodpers.isin(d1_count_types.loc[d1_count_types==1].index), 'indrel_1mes'].value_counts()
# Out:
# 1    13343385
# 3         218
# 2         117
# P          76
# 4          23
# Name: indrel_1mes, dtype: int64

# %% [markdown]
# Customers whose `ult_fec_cli_1t` is always NA and `indrel_1mes` changes

# %%
d1_changed = d1_count_types.loc[d1_count_types==2].index.tolist() # customers whose indrel_1mes changes
d1_changed = d1.loc[d1.ncodpers.isin(d1_changed)]

# %%
d1_changed_head_tail = d1_changed.groupby('ncodpers')['indrel_1mes'].apply(lambda x: (x.iloc[0], x.iloc[-1]))

# %%
d1_changed_head_tail.value_counts()
# Out:
# (3, 1)    2742
# (2, 1)    1120
# (P, 1)     730
# (4, 1)     241
# (1, 1)      23
# (1, 3)       4
# Name: indrel_1mes, dtype: int64

# %% [markdown]
# Customers whose
# - `ult_fec_cli_1t` is always NA
# - `indrel_1mes` changes from 1 to 3 then to 1 again
# - 23 customers

# %%
d11 = d1_changed_head_tail.loc[d1_changed_head_tail==(1,1)].index.tolist()
d1_changed.loc[d1_changed.ncodpers.isin(d11)].groupby('ncodpers').indrel_1mes.apply(lambda x: x.unique())

# %% [markdown]
# Customers whose
# - `ult_fec_cli_1t` is always NA
# - `indrel_1mes` changes from 1 to 3
# - `indrel_1mes` changes to 3 at the last month in 2016 May
# - 4 customers

# %%
d13 = d1_changed_head_tail.loc[d1_changed_head_tail==(1, 3)].index.tolist()
# d1_changed.loc[d1_changed.ncodpers.isin(d13)]

# %% [markdown]
# Customers whose
# - `ult_fec_cli_1t` is always NA
# - `indrel_1mes` changes from other types to 1

# %%
d31 = d1_changed_head_tail.loc[d1_changed_head_tail==(3, 1)].index.tolist()
d31 = d1_changed.loc[d1_changed.ncodpers.isin(d31)].groupby('ncodpers').indrel_1mes.apply(lambda x: sum(x.diff().fillna(0)!=0))

# %%
d21 = d1_changed_head_tail.loc[d1_changed_head_tail==(2, 1)].index.tolist()
d21 = d1_changed.loc[d1_changed.ncodpers.isin(d21)].groupby('ncodpers').indrel_1mes.apply(lambda x: sum(x.diff().fillna(0)!=0))

# %%
d21.tail()
# Out:
# ncodpers
# 1540160    1
# 1540903    1
# 1541123    1
# 1542164    1
# 1542842    1
# Name: indrel_1mes, dtype: int64

# %%
d1.loc[d1.ncodpers==1540160]
# Out:
#           ncodpers indrel_1mes fecha_dato
# 11929417   1540160           2 2016-04-28
# 13327362   1540160           1 2016-05-28

# %%
d1_changed_head_tail.value_counts().index.tolist()[2]
# Out:
# ('P', 1)

# %%
dp1 = d1_changed_head_tail.loc[d1_changed_head_tail==('P', 1)].index.tolist()

# %%
def p1(x):
    x = x.map({'P': 0, 1: 1})
    return sum(x.diff().fillna(0)!=0)

# %%
dp1 = d1_changed.loc[d1_changed.ncodpers.isin(dp1)].groupby('ncodpers').indrel_1mes.apply(p1)

# %%
dp1.value_counts()
# Out:
# 1    730
# Name: indrel_1mes, dtype: int64

# %%
dp1.head()
# Out:
# ncodpers
# 42865    1
# 43521    1
# 46374    1
# 46507    1
# 46732    1
# Name: indrel_1mes, dtype: int64

# %%
d1.loc[d1.ncodpers==46374]
# Out:
#           ncodpers indrel_1mes fecha_dato
# 4064552      46374           P 2015-07-28
# 5308797      46374           1 2015-08-28
# 5693723      46374           1 2015-09-28
# 6923255      46374           1 2015-10-28
# 7493046      46374           1 2015-11-28
# 8628757      46374           1 2015-12-28
# 9100545      46374           1 2016-01-28
# 10414974     46374           1 2016-02-28
# 11156395     46374           1 2016-03-28
# 12061700     46374           1 2016-04-28
# 13031216     46374           1 2016-05-28

# %%
d41 = d1_changed_head_tail.loc[d1_changed_head_tail==(4, 1)].index.tolist()
d41 = d1_changed.loc[d1_changed.ncodpers.isin(d41)].groupby('ncodpers').indrel_1mes.apply(lambda x: sum(x.diff().fillna(0)!=0))

# %%
d41.value_counts()
# Out:
# 1    241
# Name: indrel_1mes, dtype: int64

# %% [markdown]
# ##### Customers whose `ult_fec_cli_1t` is always not NA

# %%
e2 = e.loc[e.count_null==0].index.tolist() # customer ids whose ult_fec_cli_1t is always not NA

# %%
d2 = d.loc[d.ncodpers.isin(e2), ['ncodpers', 'indrel_1mes', 'fecha_dato', 'ult_fec_cli_1t']]
d2.sort_values(['ncodpers', 'fecha_dato'], inplace=True)

# %%
d2_group = d2.groupby('ncodpers')
a = d2_group.get_group(16817)

# %%
a
# Out:
#          ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 416600      16817           1 2015-01-28     2015-07-15
# 836621      16817           1 2015-02-28     2015-07-15
# 1674354     16817           1 2015-03-28     2015-07-15
# 2092577     16817           1 2015-04-28     2015-07-15
# 2933327     16817           1 2015-05-28     2015-07-15
# 3565387     16817           1 2015-06-28     2015-07-15
# 4079375     16817           1 2015-07-28     2015-07-15

# %%
d2_count_types = d2_group['indrel_1mes'].apply(count_types)

# %% [markdown]
# 13 customers
# - `ult_fec_cli_1t` is always not NA
# - change between two customer types

# %%
d2_count_types.value_counts()
# Out:
# 1    3468
# 2      13
# Name: indrel_1mes, dtype: int64

# %%
for c in d2_count_types.loc[d2_count_types==2].index.tolist():
    print(d2_group.get_group(c))
    print()
# Out:
#          ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 927064     315615           1 2015-02-28     2015-07-06
# 1548248    315615           1 2015-03-28     2015-07-06
# 2182526    315615           1 2015-04-28     2015-07-06
# 2842006    315615           1 2015-05-28     2015-07-06
# 3474453    315615           1 2015-06-28     2015-07-06
# 4219350    315615           1 2015-07-28     2015-07-06
# 5367757    315615           3 2015-08-28     2015-08-13
# 6763733    315615           3 2015-10-28     2015-10-27
# 8572633    315615           3 2015-12-28     2015-12-17
#
#          ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 4821594    414501           1 2015-08-28     2015-08-03
# 5510095    414501           3 2015-09-28     2015-09-03
#
#           ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 9536023     730254           3 2016-01-28     2016-01-28
# 10741515    730254           1 2016-02-28     2016-02-01
#
#          ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 5907698   1230872           3 2015-09-28     2015-09-14
# 7676783   1230872           1 2015-11-28     2015-11-03
#
#           ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 8304792    1254794           3 2015-12-28     2015-12-22
# 10060175   1254794           1 2016-02-28     2016-02-01
#
#          ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 4492720   1297355           1 2015-07-28     2015-07-20
# 6742239   1297355           3 2015-10-28     2015-10-29
#
#          ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 159848    1298328           1 2015-01-28     2015-07-09
# 1095199   1298328           1 2015-02-28     2015-07-09
# 1692418   1298328           1 2015-03-28     2015-07-09
# 2348956   1298328           1 2015-04-28     2015-07-09
# 2703221   1298328           1 2015-05-28     2015-07-09
# 3336239   1298328           1 2015-06-28     2015-07-09
# 4491970   1298328           1 2015-07-28     2015-07-09
# 9965254   1298328           3 2016-02-28     2016-02-26
#
#          ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 7798548   1357099           P 2015-11-28     2015-11-17
# 9975959   1357099           3 2016-02-28     2016-02-11
#
#           ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 4565202    1394845           1 2015-07-28     2015-07-06
# 10169239   1394845           3 2016-02-28     2016-02-11
#
#          ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 4595029   1403733           1 2015-07-28     2015-07-01
# 7805144   1403733           3 2015-11-28     2015-11-23
#
#           ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 9254243    1520177           1 2016-01-28     2016-01-04
# 10109068   1520177           3 2016-02-28     2016-02-12
#
#           ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 10123818   1528728           1 2016-02-28     2016-02-01
# 11917426   1528728           3 2016-04-28     2016-04-08
#
#           ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 11926747   1542940           1 2016-04-28     2016-04-04
# 13329310   1542940           3 2016-05-28     2016-05-04

# %%
k1 = d2_count_types.loc[d2_count_types==1].index.tolist() # list of ncodpers whose have only one type

# %%
k2 = d2.loc[d2.ncodpers.isin(k1)].groupby('ncodpers').indrel_1mes.apply(lambda x: x.iloc[0]) # customer types for customers only have one type

# %%
k2.value_counts()
# Out:
# 1    2997
# 3     422
# P      25
# 4      14
# 2      10
# Name: indrel_1mes, dtype: int64

# %%
k2.head(10)
# Out:
# ncodpers
# 16817    1
# 18352    1
# 18699    1
# 19427    1
# 21382    1
# 23638    1
# 24032    1
# 24170    3
# 26036    1
# 26652    3
# Name: indrel_1mes, dtype: object

# %%
d2.loc[d2.ncodpers==18352]
# Out:
#          ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 417413      18352           1 2015-01-28     2015-07-03
# 835764      18352           1 2015-02-28     2015-07-03
# 1673520     18352           1 2015-03-28     2015-07-03
# 2091741     18352           1 2015-04-28     2015-07-03
# 2934199     18352           1 2015-05-28     2015-07-03
# 3566258     18352           1 2015-06-28     2015-07-03
# 4078578     18352           1 2015-07-28     2015-07-03

# %%
d2.loc[d2.ncodpers==24170]
# Out:
#          ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 5315823     24170           3 2015-08-28     2015-08-19

# %%
d2.loc[d2.ncodpers==26652]
# Out:
#          ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 8620173     26652           3 2015-12-28     2015-12-02

# %%
k3 = k2.loc[k2!=1].index.tolist() # customers who have only one customer type and the type is not 1

# %%
len(k3)
# Out:
# 471

# %% [markdown]
# 22 customers
# - have only one customer type but multiple rows
# - either `indrel_1mes` wrong, or `indrel_1mes==2` include `indrel_1mes==1`
# - some record are missing
# - become primary and then leave multiple times

# %%
for c in k3:
    print(d2.loc[d2.ncodpers==c])
    print()
# Out:
#          ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 
#
#           ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 10138179   1506672           3 2016-02-28     2016-02-10
# 11961698   1506672           3 2016-04-28     2016-04-08
#
#           ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 11962176   1508200           3 2016-04-28     2016-04-04
#
#           ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 10134817   1510158           3 2016-02-28     2016-02-08
#
#           ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 10944063   1514446           3 2016-03-28     2016-03-03
#
#           ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 10113218   1516569           3 2016-02-28     2016-02-15
#
#           ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 10948923   1519276           3 2016-03-28     2016-03-24
#
#          ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 9253578   1519877           3 2016-01-28     2016-01-11
#
#           ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 10937086   1522993           2 2016-03-28     2016-03-18
#
#           ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 10110705   1524930           3 2016-02-28     2016-02-19
#
#           ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 10935474   1525850           3 2016-03-28     2016-03-11
#
#           ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 13349075   1530537           3 2016-05-28     2016-05-04
#
#           ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 13352412   1532022           2 2016-05-28     2016-05-30
#
#           ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 13332083   1534013           4 2016-05-28     2016-05-26
#
#           ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 11248876   1534122           3 2016-03-28     2016-03-14
#
#           ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 11910969   1535206           3 2016-04-28     2016-04-04
#
#           ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 11246203   1535330           3 2016-03-28     2016-03-02
#
#           ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 11910135   1538415           3 2016-04-28     2016-04-18
#
#           ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 13330599   1542008           3 2016-05-28     2016-05-05
#
#           ncodpers indrel_1mes fecha_dato ult_fec_cli_1t
# 13330408   1542376           3 2016-05-28     2016-05-26

# %% [markdown]
# #### `ult_fec_cli_1t` and `indrel`
#
# `indrel`: 1 (First/Primary), 99 (Primary customer during the month but not at the end of the month)
#
# 1. `indrel` depends on `ult_fec_cli_1t`:
#     - `ult_fec_cli_1t` not NA, `indrel==99`
#     - `ult_fec_cli_1t` is NA, `indrel==1` or `indrel=='unknown'`
# 2. What is the definition of primary customer?
#     - Almost all the customers are primary?
#     - How about types indicated by `indrel_1mes`, like co-owner, potential, former primary, former co-owner?
# 3. `indrel` only indicates if `ult_fec_cli_1t` of the same row is NA or not
#     - `ult_fec_cli_1t` is NA, `indrel==1`
#     - `ult_fec_cli_1t` is not NA, `indrel==99`

# %% [markdown]
# However, `indrel==99` for all samples with `ult_fec_cli_1t` not NA, this is not consistent with the definition of `ult_fec_cli_1t`

# %%
a.indrel.value_counts()
# Out:
# 99.0    24793
# Name: indrel, dtype: int64

# %% [markdown]
# And for samples with `ult_fec_cli_1t` is NA, `indrel` is either 1 or 'unknown'

# %%
df.loc[df.ult_fec_cli_1t.isnull(), 'indrel'].value_counts()
# Out:
# 1.0        13594782
# unknown       27734
# Name: indrel, dtype: int64

# %% [markdown]
# So, `indrel` is not very informative, or we can set `indrel=='unknown'` to `indrel=1`

# %%
a.indrel.value_counts()
# Out:
# 99.0    24793
# Name: indrel, dtype: int64

# %% [markdown]
# If a customer has both `ult_fec_cli_1t` NA and not NA, what is `indrel`?

# %%
a = df.loc[:, ['ncodpers', 'ult_fec_cli_1t', 'indrel']].copy()
a.ult_fec_cli_1t = a.ult_fec_cli_1t.isnull()

# %%
a.groupby(['ult_fec_cli_1t', 'indrel']).ncodpers.count()
# Out:
# ult_fec_cli_1t  indrel
# False           99.0          24793
# True            1.0        13594782
#                 unknown       27734
# Name: ncodpers, dtype: int64

# %%
a.loc[~a.ult_fec_cli_1t, 'ncodpers'].value_counts().head()
# Out:
# 861411     9
# 315615     9
# 1381117    9
# 1344175    8
# 1372228    8
# Name: ncodpers, dtype: int64

# %%
a.loc[a.ncodpers==861411]
# Out:
#           ncodpers  ult_fec_cli_1t indrel
# 728904      861411           False     99
# 1367124     861411           False     99
# 1985282     861411           False     99
# 3042881     861411           False     99
# 3661546     861411           False     99
# 3985371     861411           False     99
# 7078406     861411            True      1
# 7957333     861411            True      1
# 8253103     861411            True      1
# 9570609     861411           False     99
# 10738595    861411           False     99
# 11343529    861411            True      1
# 11992066    861411           False     99

# %% [markdown]
# #### `ult_fec_cli_1t` and `indrel_1mes`
#
# Customer types at the beginning of the month.
#
# - Most of the samples are 1. They are primary at the beginning of the month, but changed later.
# - Some samples are 3. They were primary before.
#     - If `ult_fec_cli_1t` is in the same month of `fecha_dato`, he/she becomes primary and leave quickly in the same month
#     - If `ult_fec_cli_1t` is in a later month relative to `fecha_dato`, he/she becomes primary in the same month?
# - Other values
#     - Investigate later

# %%
a.indrel_1mes.value_counts()
# Out:
# 1.0    8322
# 1.0    6174
# 1      5810
# 3.0     208
# 3       185
# 3.0     124
# P        28
# 2.0       8
# 4.0       7
# 4.0       7
# 2         5
# 2.0       3
# Name: indrel_1mes, dtype: int64

# %% [markdown]
# Samples that were primary at the beginning of the month, but changed some time in the same month.
#
# Note, `ult_fec_cli_1t` can be a future month for a sample, indicating that this period of primary membership terminates later.

# %%
a.loc[(a.ult_fec_cli_1t-a.fecha_dato)]

# %%
b = a.ncodpers.value_counts()
plt.rcParams.update({'font.size': 22})
plt.figure(figsize=(16, 9))
plt.plot(b.loc[b>1].values)
plt.title('Around 1000 customers register and churn multiple times')
# Out:
# Text(0.5,1,'Around 1000 customers register and churn multiple times')

# %%
b.loc[b>1].head()
# Out:
# 861411     9
# 315615     9
# 1381117    9
# 1344175    8
# 1372228    8
# Name: ncodpers, dtype: int64

# %% [markdown]
# It looks like the month of `ult_fec_cli_1t` is no larger than the month of `fecha_dato`

# %%
a.fecha_dato = pd.to_datetime(a.fecha_dato)
a.fecha_alta = pd.to_datetime(a.fecha_alta)
a.ult_fec_cli_1t = pd.to_datetime(a.ult_fec_cli_1t)

# %%
b = a.ult_fec_cli_1t-a.fecha_dato

# %%
a.indrel_1mes.value_counts()
# Out:
# 1.0    8322
# 1.0    6174
# 1      5810
# 3.0     208
# 3       185
# 3.0     124
# P        28
# 2.0       8
# 4.0       7
# 4.0       7
# 2         5
# 2.0       3
# Name: indrel_1mes, dtype: int64

# %%
b.value_counts()
# Out:
# -4 days     1337
# 0 days      1102
# -10 days     823
# -17 days     786
# -27 days     769
# -13 days     743
# -7 days      726
# -12 days     726
# -26 days     725
# -19 days     708
# -11 days     706
# -24 days     686
# -6 days      679
# -2 days      677
# -9 days      677
# -23 days     644
# -14 days     644
# -1 days      636
# -18 days     620
# -20 days     610
# -21 days     603
# -15 days     579
# -25 days     571
# -5 days      561
# -8 days      551
# -3 days      533
# -16 days     478
# -22 days     438
# 1 days       395
# 2 days       339
#             ...
# 136 days      25
# 183 days      25
# 145 days      25
# 16 days       25
# 60 days       25
# 77 days       24
# 180 days      24
# 152 days      24
# 121 days      24
# 47 days       24
# 176 days      24
# 149 days      24
# 90 days       23
# 161 days      23
# 130 days      22
# 65 days       22
# 41 days       22
# 10 days       22
# 96 days       22
# 102 days      22
# 71 days       21
# 35 days       21
# 79 days       19
# 155 days      19
# 18 days       18
# 138 days      18
# 49 days       18
# 4 days        18
# 110 days      18
# 169 days      17
# Length: 160, dtype: int64

# %%
test = pd.read_csv('../input/test_ver2.csv')
# Out:
# C:\Users\lyaa\AppData\Local\Continuum\miniconda3\envs\kaggle\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
