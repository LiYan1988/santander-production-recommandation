# %%
import os
if os.name=='nt':
    try:
        mingw_path = 'C:\\Program Files\\mingw-w64\\x86_64-8.1.0-posix-seh-rt_v6-rev0\\mingw64\\bin'
        os.environ['PATH'] = mingw_path + ';' + os.environ['PATH']
    except:
        pass
    
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tqdm

tqdm.tqdm.pandas()

# %matplotlib inline

# %%
df = pd.read_csv('../input/train_ver2.csv')
df2 = df.copy()
# Out:
# C:\Users\home\Anaconda3\envs\kaggle\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (5,8,11,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
ult_null = pd.read_hdf('../input/data.hdf', 'train_ult_null_count')

# %%
ncodpers_mixnull = ult_null.loc[(ult_null.count_ult_notnull>0) & (ult_null.count_ult_null>0)].index.tolist()

# %%
df.ult_fec_cli_1t = pd.to_datetime(df.ult_fec_cli_1t)
df.fecha_dato = pd.to_datetime(df.fecha_dato)
df.fecha_alta = pd.to_datetime(df.fecha_alta)

# %%
df.sort_values(['ncodpers', 'fecha_dato'], inplace=True)

# %%
df.loc[df.ncodpers.isin(ncodpers_mixnull), 'ult_fec_cli_1t'] = \
    df.loc[df.ncodpers.isin(ncodpers_mixnull), 'ult_fec_cli_1t'].fillna(method='bfill')

# %%
df.loc[df.ncodpers.isin(ncodpers_mixnull), ['ncodpers', 'ult_fec_cli_1t']].head()
# Out:
#          ncodpers ult_fec_cli_1t
# 4078994     15891     2015-08-05
# 5319232     15891     2015-08-05
# 4079035     16136     2016-03-17
# 5319290     16136     2016-03-17
# 5705240     16136     2016-03-17

# %%
df.age = pd.to_numeric(df.age, errors='coerce')

# %%
df.antiguedad = pd.to_numeric(df.antiguedad, errors='coerce')

# %%
fecha_dato = pd.DatetimeIndex(df.fecha_dato)
fecha_alta = pd.DatetimeIndex(df.fecha_alta)
fecha_diff = (fecha_dato.year-fecha_alta.year)*12 + (fecha_dato.month-fecha_alta.month)

# %%
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\Anaconda3\envs\kaggle\lib\site-packages\pandas\core\frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6865                 values = self.values
# -> 6866                 result = f(values)
#    6867
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\pandas\core\frame.py in f(x)
#    6856         def f(x):
# -> 6857             return op(x, axis=axis, skipna=skipna, **kwds)
#    6858
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      76                 with np.errstate(invalid='ignore'):
# ---> 77                     return f(*args, **kwargs)
#      78             except ValueError as e:
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\pandas\core\nanops.py in nansum(values, axis, skipna, min_count)
#     329 def nansum(values, axis=None, skipna=True, min_count=0):
# --> 330     values, mask, dtype, dtype_max = _get_values(values, skipna, 0)
#     331     dtype_sum = dtype_max
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\pandas\core\nanops.py in _get_values(values, skipna, fill_value, fill_value_typ, isfinite, copy)
#     225         if dtype_ok:
# --> 226             np.putmask(values, mask, fill_value)
#     227
#
# MemoryError:
#
# During handling of the above exception, another exception occurred:
#
# MemoryError                               Traceback (most recent call last)
# <ipython-input-109-629914d6d1c7> in <module>()
# ----> 1 df.isnull().sum()
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#    9591                                       skipna=skipna, min_count=min_count)
#    9592         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 9593                             numeric_only=numeric_only, min_count=min_count)
#    9594
#    9595     return set_function_name(stat_func, name, cls)
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\pandas\core\frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6908                     raise_with_traceback(e)
#    6909                 with np.errstate(all='ignore'):
# -> 6910                     result = f(data.values)
#    6911                 labels = data._get_agg_axis(axis)
#    6912         else:
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\pandas\core\frame.py in f(x)
#    6855
#    6856         def f(x):
# -> 6857             return op(x, axis=axis, skipna=skipna, **kwds)
#    6858
#    6859         # exclude timedelta/datetime unless we are uniform types
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      75             try:
#      76                 with np.errstate(invalid='ignore'):
# ---> 77                     return f(*args, **kwargs)
#      78             except ValueError as e:
#      79                 # we want to transform an object array
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\pandas\core\nanops.py in nansum(values, axis, skipna, min_count)
#     328 @disallow('M8')
#     329 def nansum(values, axis=None, skipna=True, min_count=0):
# --> 330     values, mask, dtype, dtype_max = _get_values(values, skipna, 0)
#     331     dtype_sum = dtype_max
#     332     if is_float_dtype(dtype):
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\pandas\core\nanops.py in _get_values(values, skipna, fill_value, fill_value_typ, isfinite, copy)
#     210         mask = _isfinite(values)
#     211     else:
# --> 212         mask = isna(values)
#     213
#     214     dtype = values.dtype
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\pandas\core\dtypes\missing.py in isna(obj)
#     104     Name: 1, dtype: bool
#     105     """
# --> 106     return _isna(obj)
#     107
#     108
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\pandas\core\dtypes\missing.py in _isna_new(obj)
#     118     elif isinstance(obj, (ABCSeries, np.ndarray, ABCIndexClass,
#     119                           ABCExtensionArray)):
# --> 120         return _isna_ndarraylike(obj)
#     121     elif isinstance(obj, ABCGeneric):
#     122         return obj._constructor(obj._data.isna(func=isna))
#
# ~\Anaconda3\envs\kaggle\lib\site-packages\pandas\core\dtypes\missing.py in _isna_ndarraylike(obj)
#     218         result = values.view('i8') == iNaT
#     219     else:
# --> 220         result = np.isnan(values)
#     221
#     222     # box
#
# MemoryError:

# %%
df.loc[df.antiguedad<0]
# Out:
#          fecha_dato  ncodpers ind_empleado pais_residencia sexo   age  \
# 452687   2015-01-28    138388            N              ES    V  51.0
# 800687   2015-02-28    138388            N              ES    V  51.0
# 1422227  2015-03-28    138388            N              ES    V  51.0
# 2056813  2015-04-28    138388            N              ES    V  51.0
# 2969610  2015-05-28    138388            N              ES    V  51.0
# 3601557  2015-06-28    138388            N              ES    V  51.0
# 4020536  2015-07-28    138388            N              ES    V  51.0
# 5257294  2015-08-28    138388            N              ES    V  51.0
# 5647050  2015-09-28    138388            N              ES    V  51.0
# 6968353  2015-10-28    138388            N              ES    V  51.0
# 7616647  2015-11-28    138388            N              ES    V  51.0
# 8678128  2015-12-28    138388            N              ES    V  51.0
# 9114602  2016-01-28    138388            N              ES    V  51.0
# 10405076 2016-02-28    138388            N              ES    V  51.0
# 11109978 2016-03-28    138388            N              ES    V  52.0
# 12041260 2016-04-28    138388            N              ES    V  52.0
# 12964573 2016-05-28    138388            N              ES    V  52.0
# 461981   2015-01-28    162278            N              ES    V  66.0
# 788786   2015-02-28    162278            N              ES    V  66.0
# 1412242  2015-03-28    162278            N              ES    V  66.0
# 2045024  2015-04-28    162278            N              ES    V  66.0
# 2980914  2015-05-28    162278            N              ES    V  66.0
# 3613493  2015-06-28    162278            N              ES    V  66.0
# 4008831  2015-07-28    162278            N              ES    V  66.0
# 5295097  2015-08-28    162278            N              ES    V  67.0
# 5683025  2015-09-28    162278            N              ES    V  67.0
# 6982647  2015-10-28    162278            N              ES    V  67.0
# 7658437  2015-11-28    162278            N              ES    V  67.0
# 8644608  2015-12-28    162278            N              ES    V  67.0
# 9045555  2016-01-28    162278            N              ES    V  67.0
# 10396442 2016-02-28    162278            N              ES    V  67.0
# 11097857 2016-03-28    162278            N              ES    V  67.0
# 12111000 2016-04-28    162278            N              ES    V  67.0
# 12952748 2016-05-28    162278            N              ES    V  67.0
# 10771018 2016-02-28    750561            N              ES    V  36.0
# 11361026 2016-03-28    750561            N              ES    V  37.0
# 11978594 2016-04-28    750561            N              ES    V  37.0
# 12911749 2016-05-28    750561            N              ES    V  37.0
#
#          fecha_alta  ind_nuevo  antiguedad  indrel       ...         \
# 452687   1999-07-16        0.0   -999999.0     1.0       ...
# 800687   1999-07-16        0.0   -999999.0     1.0       ...
# 1422227  1999-07-16        0.0   -999999.0     1.0       ...
# 2056813  1999-07-16        0.0   -999999.0     1.0       ...
# 2969610  1999-07-16        0.0   -999999.0     1.0       ...
# 3601557  1999-07-16        0.0   -999999.0     1.0       ...
# 4020536  1999-07-16        0.0   -999999.0     1.0       ...
# 5257294  1999-07-16        0.0   -999999.0     1.0       ...
# 5647050  1999-07-16        0.0   -999999.0     1.0       ...
# 6968353  1999-07-16        0.0   -999999.0     1.0       ...
# 7616647  1999-07-16        0.0   -999999.0     1.0       ...
# 8678128  1999-07-16        0.0   -999999.0     1.0       ...
# 9114602  1999-07-16        0.0   -999999.0     1.0       ...
# 10405076 1999-07-16        0.0   -999999.0     1.0       ...
# 11109978 1999-07-16        0.0   -999999.0     1.0       ...
